# %% [markdown]
# # **New**

# %%
# %%writefile songlist.txt
# # A.R. Rahman full-albums (200 albums, 1456 songs) — generated 2026-08-04
# Pudhiya Mugam (Original Motion Picture Soundtrack) (1993):
#   https://music.apple.com/in/song/586976577
#   https://music.apple.com/in/song/586976578
#   https://music.apple.com/in/song/586976579
#   https://music.apple.com/in/song/586976580
#   https://music.apple.com/in/song/586976582
#   https://music.apple.com/in/song/586976585
# Roja (Malayalam) [Original Motion Picture Soundtrack] (1993):
#   https://music.apple.com/in/song/586988773
#   https://music.apple.com/in/song/586988827
#   https://music.apple.com/in/song/586988828
#   https://music.apple.com/in/song/586988871
#   https://music.apple.com/in/song/586988872
#   https://music.apple.com/in/song/586988873
# Roja (Original Motion Picture Soundtrack) (1993):
#   https://music.apple.com/in/song/587001059
#   https://music.apple.com/in/song/587001060
#   https://music.apple.com/in/song/587001061
#   https://music.apple.com/in/song/587001062
#   https://music.apple.com/in/song/587001063
#   https://music.apple.com/in/song/587001065
#   https://music.apple.com/in/song/587001066
#   https://music.apple.com/in/song/587001189
#   https://music.apple.com/in/song/587001190
#   https://music.apple.com/in/song/587001191
#   https://music.apple.com/in/song/587001193
#   https://music.apple.com/in/song/587001195
# Thiruda Thiruda (Original Motion Picture Soundtrack) (1993):
#   https://music.apple.com/in/song/586962313
#   https://music.apple.com/in/song/586962314
#   https://music.apple.com/in/song/586962319
#   https://music.apple.com/in/song/586962320
#   https://music.apple.com/in/song/586962322
#   https://music.apple.com/in/song/586962323
# Donga Donga (Original Motion Picture Soundtrack) (1994):
#   https://music.apple.com/in/song/586992233
#   https://music.apple.com/in/song/586992237
#   https://music.apple.com/in/song/586992248
#   https://music.apple.com/in/song/586992293
#   https://music.apple.com/in/song/586992412
#   https://music.apple.com/in/song/586992555
#   https://music.apple.com/in/song/586992563
#   https://music.apple.com/in/song/586992614
# Duet (Original Motion Picture Soundtrack) (1994):
#   https://music.apple.com/in/song/1578440257
#   https://music.apple.com/in/song/1578440258
#   https://music.apple.com/in/song/1578440259
#   https://music.apple.com/in/song/1578440260
#   https://music.apple.com/in/song/1578440261
#   https://music.apple.com/in/song/1578440262
#   https://music.apple.com/in/song/1578440263
#   https://music.apple.com/in/song/1578440264
#   https://music.apple.com/in/song/1578440265
#   https://music.apple.com/in/song/1578440266
#   https://music.apple.com/in/song/1578440267
#   https://music.apple.com/in/song/1578440268
#   https://music.apple.com/in/song/1578440269
# Bombay (Original Soundtrack) [OST] (1994):
#   https://music.apple.com/in/song/1442492391
#   https://music.apple.com/in/song/1442492561
#   https://music.apple.com/in/song/1442492571
#   https://music.apple.com/in/song/1442492574
#   https://music.apple.com/in/song/1442492576
#   https://music.apple.com/in/song/1442492584
# Bombay (Original Motion Picture Soundtrack) (1995):
#   https://music.apple.com/in/song/1577791235
#   https://music.apple.com/in/song/1577791956
#   https://music.apple.com/in/song/1577791957
#   https://music.apple.com/in/song/1577791958
#   https://music.apple.com/in/song/1577791959
#   https://music.apple.com/in/song/1577791960
#   https://music.apple.com/in/song/1577791961
#   https://music.apple.com/in/song/1577791962
#   https://music.apple.com/in/song/1577791963
# Bombay (Original Motion Picture Soundtrack) (1995):
#   https://music.apple.com/in/song/1442934813
#   https://music.apple.com/in/song/1442934820
#   https://music.apple.com/in/song/1442935093
#   https://music.apple.com/in/song/1442935097
#   https://music.apple.com/in/song/1442935103
#   https://music.apple.com/in/song/1442935113
# Rangeela (Original Motion Picture Soundtrack) (1995):
#   https://music.apple.com/in/song/1550793662
#   https://music.apple.com/in/song/1550793663
#   https://music.apple.com/in/song/1550793664
#   https://music.apple.com/in/song/1550793665
#   https://music.apple.com/in/song/1550793906
#   https://music.apple.com/in/song/1550793907
#   https://music.apple.com/in/song/1550793908
#   https://music.apple.com/in/song/1550793909
#   https://music.apple.com/in/song/1550793911
# Roja (Marathi) [Original Motion Picture Soundtrack] (1996):
#   https://music.apple.com/in/song/586984145
#   https://music.apple.com/in/song/586984213
#   https://music.apple.com/in/song/586984214
#   https://music.apple.com/in/song/586984217
#   https://music.apple.com/in/song/586984219
#   https://music.apple.com/in/song/586984220
#   https://music.apple.com/in/song/586984221
# Indian (Original Motion Picture Soundtrack) (1996):
#   https://music.apple.com/in/song/1577789776
#   https://music.apple.com/in/song/1577789777
#   https://music.apple.com/in/song/1577789778
#   https://music.apple.com/in/song/1577789779
#   https://music.apple.com/in/song/1577789780
# Prema Desam (Original Motion Picture Soundtrack) (1996):
#   https://music.apple.com/in/song/1387112732
#   https://music.apple.com/in/song/1387112733
#   https://music.apple.com/in/song/1387113221
#   https://music.apple.com/in/song/1387113222
#   https://music.apple.com/in/song/1387113231
#   https://music.apple.com/in/song/1387113244
# Love Birds (Original Motion Picture Soundtrack) (1996):
#   https://music.apple.com/in/song/935074149
#   https://music.apple.com/in/song/935074167
#   https://music.apple.com/in/song/935074178
#   https://music.apple.com/in/song/935074246
#   https://music.apple.com/in/song/935074248
# Kadhal Desam (Original Motion Picture Soundtrack) (1996):
#   https://music.apple.com/in/song/1561221919
#   https://music.apple.com/in/song/1561221921
#   https://music.apple.com/in/song/1561221922
#   https://music.apple.com/in/song/1561221924
#   https://music.apple.com/in/song/1561221925
#   https://music.apple.com/in/song/1561221927
# Vande Mataram (1997):
#   https://music.apple.com/in/song/274118911
#   https://music.apple.com/in/song/274119053
#   https://music.apple.com/in/song/274119061
#   https://music.apple.com/in/song/274119076
#   https://music.apple.com/in/song/274119091
#   https://music.apple.com/in/song/274119106
#   https://music.apple.com/in/song/274119120
# Merupu Kalalu (Original Motion Picture Soundtrack) (1997):
#   https://music.apple.com/in/song/1175817940
#   https://music.apple.com/in/song/1175818181
#   https://music.apple.com/in/song/1175818185
#   https://music.apple.com/in/song/1175818187
#   https://music.apple.com/in/song/1175818191
#   https://music.apple.com/in/song/1175818195
# 1998 A. R. Rahman Hits Songs (1998):
#   https://music.apple.com/in/song/998459103
#   https://music.apple.com/in/song/998459116
#   https://music.apple.com/in/song/998459380
#   https://music.apple.com/in/song/998459425
#   https://music.apple.com/in/song/998459426
#   https://music.apple.com/in/song/998459745
#   https://music.apple.com/in/song/998459841
#   https://music.apple.com/in/song/998459842
#   https://music.apple.com/in/song/998459850
#   https://music.apple.com/in/song/998459852
#   https://music.apple.com/in/song/998460085
#   https://music.apple.com/in/song/998460247
#   https://music.apple.com/in/song/998460373
#   https://music.apple.com/in/song/998460380
#   https://music.apple.com/in/song/998460542
#   https://music.apple.com/in/song/998460543
#   https://music.apple.com/in/song/998460544
#   https://music.apple.com/in/song/998460790
#   https://music.apple.com/in/song/998460791
#   https://music.apple.com/in/song/998460792
#   https://music.apple.com/in/song/998460794
#   https://music.apple.com/in/song/998460799
#   https://music.apple.com/in/song/998460802
#   https://music.apple.com/in/song/998460808
#   https://music.apple.com/in/song/998460813
# Jeans (Original Motion Picture Soundtrack) (1998):
#   https://music.apple.com/in/song/686344289
#   https://music.apple.com/in/song/686344291
#   https://music.apple.com/in/song/686344294
#   https://music.apple.com/in/song/686344297
#   https://music.apple.com/in/song/686344302
#   https://music.apple.com/in/song/686344370
# Taj Mahal (Original Motion Picture Soundtrack) (1998):
#   https://music.apple.com/in/song/686306896
#   https://music.apple.com/in/song/686306931
#   https://music.apple.com/in/song/686306991
#   https://music.apple.com/in/song/686306995
#   https://music.apple.com/in/song/686306999
#   https://music.apple.com/in/song/686307000
#   https://music.apple.com/in/song/686307001
#   https://music.apple.com/in/song/686307007
#   https://music.apple.com/in/song/686307008
#   https://music.apple.com/in/song/686307015
# Dil Se (Original Motion Picture Soundtrack) (1998):
#   https://music.apple.com/in/song/1130322151
#   https://music.apple.com/in/song/1130322192
#   https://music.apple.com/in/song/1130322222
#   https://music.apple.com/in/song/1130322244
#   https://music.apple.com/in/song/1130322254
#   https://music.apple.com/in/song/1130322255
# Uyire (Original Motion Picture Soundtrack) (1998):
#   https://music.apple.com/in/song/1491710689
#   https://music.apple.com/in/song/1491710696
#   https://music.apple.com/in/song/1491710700
#   https://music.apple.com/in/song/1491710704
#   https://music.apple.com/in/song/1491711047
#   https://music.apple.com/in/song/1491711055
# Doli Saja Ke Rakhna (Original Motion Picture Soundtrack) (1998):
#   https://music.apple.com/in/song/1140468371
#   https://music.apple.com/in/song/1140468372
#   https://music.apple.com/in/song/1140468376
#   https://music.apple.com/in/song/1140468380
#   https://music.apple.com/in/song/1140468381
#   https://music.apple.com/in/song/1140468383
#   https://music.apple.com/in/song/1140468385
#   https://music.apple.com/in/song/1140468386
# Jeans (Original Motion Picture Soundtrack) (1999):
#   https://music.apple.com/in/song/933551409
#   https://music.apple.com/in/song/933551410
#   https://music.apple.com/in/song/933551411
#   https://music.apple.com/in/song/933551412
#   https://music.apple.com/in/song/933551413
#   https://music.apple.com/in/song/933551414
# Padayappa (Original Motion Picture Soundtrack) (1999):
#   https://music.apple.com/in/song/946197227
#   https://music.apple.com/in/song/946197232
#   https://music.apple.com/in/song/946197235
#   https://music.apple.com/in/song/946197240
#   https://music.apple.com/in/song/946197289
#   https://music.apple.com/in/song/946197291
# Jodi (Original Motion Picture Soundtrack) (1999):
#   https://music.apple.com/in/song/686349894
#   https://music.apple.com/in/song/686349898
#   https://music.apple.com/in/song/686349900
#   https://music.apple.com/in/song/686349902
#   https://music.apple.com/in/song/686349904
#   https://music.apple.com/in/song/686349906
#   https://music.apple.com/in/song/686350051
# Thaalam (Original Motion Picture Soundtrack) (1999):
#   https://music.apple.com/in/song/686949894
#   https://music.apple.com/in/song/686949895
#   https://music.apple.com/in/song/686949896
#   https://music.apple.com/in/song/686949897
#   https://music.apple.com/in/song/686949898
#   https://music.apple.com/in/song/686949899
#   https://music.apple.com/in/song/686949900
#   https://music.apple.com/in/song/686949901
#   https://music.apple.com/in/song/686949903
# 1947 Earth (Original Motion Picture Soundtrack) (1999):
#   https://music.apple.com/in/song/1120993689
#   https://music.apple.com/in/song/1120993690
#   https://music.apple.com/in/song/1120993764
#   https://music.apple.com/in/song/1120993765
#   https://music.apple.com/in/song/1120993766
#   https://music.apple.com/in/song/1120993767
#   https://music.apple.com/in/song/1120993774
#   https://music.apple.com/in/song/1120993778
#   https://music.apple.com/in/song/1120993779
# Taal (Original Motion Picture Soundtrack) (1999):
#   https://music.apple.com/in/song/1536519639
#   https://music.apple.com/in/song/1536519640
#   https://music.apple.com/in/song/1536519643
#   https://music.apple.com/in/song/1536519650
#   https://music.apple.com/in/song/1536519653
#   https://music.apple.com/in/song/1536519659
#   https://music.apple.com/in/song/1536519878
#   https://music.apple.com/in/song/1536519883
#   https://music.apple.com/in/song/1536519891
#   https://music.apple.com/in/song/1536519896
#   https://music.apple.com/in/song/1536519898
#   https://music.apple.com/in/song/1536519902
# Dil Hi Dil Mein (Original Motion Picture Soundtrack) (1999):
#   https://music.apple.com/in/song/302379628
#   https://music.apple.com/in/song/302379630
#   https://music.apple.com/in/song/302379631
#   https://music.apple.com/in/song/302379635
#   https://music.apple.com/in/song/302379638
#   https://music.apple.com/in/song/302379641
# Pukar (Original Motion Picture Soundtrack) (1999):
#   https://music.apple.com/in/song/1126859340
#   https://music.apple.com/in/song/1126859453
#   https://music.apple.com/in/song/1126859605
#   https://music.apple.com/in/song/1126859606
#   https://music.apple.com/in/song/1126859608
#   https://music.apple.com/in/song/1126859611
# Premikula Roju (Original Motion Picture Soundtrack) (1999):
#   https://music.apple.com/in/song/1329146897
#   https://music.apple.com/in/song/1329146898
#   https://music.apple.com/in/song/1329146899
#   https://music.apple.com/in/song/1329146900
#   https://music.apple.com/in/song/1329146904
#   https://music.apple.com/in/song/1329146905
# Thakshak (Original Motion Picture Soundtrack) (1999):
#   https://music.apple.com/in/song/1282436994
#   https://music.apple.com/in/song/1282437020
#   https://music.apple.com/in/song/1282437027
#   https://music.apple.com/in/song/1282437034
#   https://music.apple.com/in/song/1282437193
#   https://music.apple.com/in/song/1282437202
#   https://music.apple.com/in/song/1282437209
#   https://music.apple.com/in/song/1282437218
#   https://music.apple.com/in/song/1282437409
# Jan Gan Man (2000):
#   https://music.apple.com/in/song/455937930
# Alaipayuthey (Original Motion Picture Soundtrack) (2000):
#   https://music.apple.com/in/song/1338740583
#   https://music.apple.com/in/song/1338740584
#   https://music.apple.com/in/song/1338740586
#   https://music.apple.com/in/song/1338740587
#   https://music.apple.com/in/song/1338740590
#   https://music.apple.com/in/song/1338741012
#   https://music.apple.com/in/song/1338741013
#   https://music.apple.com/in/song/1338741014
#   https://music.apple.com/in/song/1338741015
#   https://music.apple.com/in/song/1338741016
#   https://music.apple.com/in/song/1338741017
#   https://music.apple.com/in/song/1338741021
#   https://music.apple.com/in/song/1338741022
#   https://music.apple.com/in/song/1338741026
#   https://music.apple.com/in/song/1338741028
#   https://music.apple.com/in/song/1338741029
#   https://music.apple.com/in/song/1338741035
#   https://music.apple.com/in/song/1338741037
#   https://music.apple.com/in/song/1338741038
#   https://music.apple.com/in/song/1338741137
#   https://music.apple.com/in/song/1338741138
#   https://music.apple.com/in/song/1338741139
#   https://music.apple.com/in/song/1338741140
#   https://music.apple.com/in/song/1338741141
# Zubeidaa (Original Motion Picture Soundtrack) (2000):
#   https://music.apple.com/in/song/302388547
#   https://music.apple.com/in/song/302388549
#   https://music.apple.com/in/song/302388554
#   https://music.apple.com/in/song/302388581
#   https://music.apple.com/in/song/302388592
#   https://music.apple.com/in/song/302388595
#   https://music.apple.com/in/song/302388596
#   https://music.apple.com/in/song/302388601
# Sakhi (Original Motion Picture Soundtrack) (2000):
#   https://music.apple.com/in/song/1329150079
#   https://music.apple.com/in/song/1329150080
#   https://music.apple.com/in/song/1329150081
#   https://music.apple.com/in/song/1329150082
#   https://music.apple.com/in/song/1329150083
#   https://music.apple.com/in/song/1329150084
#   https://music.apple.com/in/song/1329150086
# Lagaan (Original Motion Picture Soundtrack) (2001):
#   https://music.apple.com/in/song/305751199
#   https://music.apple.com/in/song/305751200
#   https://music.apple.com/in/song/305751202
#   https://music.apple.com/in/song/305751207
#   https://music.apple.com/in/song/305751208
#   https://music.apple.com/in/song/305751212
#   https://music.apple.com/in/song/305751217
#   https://music.apple.com/in/song/305751218
# Amrutha (Original Motion Picture Soundtrack) (2002):
#   https://music.apple.com/in/song/928329415
#   https://music.apple.com/in/song/928329416
#   https://music.apple.com/in/song/928329417
#   https://music.apple.com/in/song/928329430
#   https://music.apple.com/in/song/928329443
# Baba (Original Motion Picture Soundtrack) (2002):
#   https://music.apple.com/in/song/928329911
#   https://music.apple.com/in/song/928329912
#   https://music.apple.com/in/song/928329914
#   https://music.apple.com/in/song/928329915
#   https://music.apple.com/in/song/928329916
#   https://music.apple.com/in/song/928329919
# Baba (Original Motion Picture Soundtrack) (2002):
#   https://music.apple.com/in/song/946193330
#   https://music.apple.com/in/song/946193344
#   https://music.apple.com/in/song/946193345
#   https://music.apple.com/in/song/946193347
#   https://music.apple.com/in/song/946193348
# Kaadhal Virus (Original Motion Picture Soundtrack) (2002):
#   https://music.apple.com/in/song/302388219
#   https://music.apple.com/in/song/302388224
#   https://music.apple.com/in/song/302388228
#   https://music.apple.com/in/song/302388241
#   https://music.apple.com/in/song/302388266
#   https://music.apple.com/in/song/302388276
# Saathiya (Original Motion Picture Soundtrack) (2002):
#   https://music.apple.com/in/song/673594503
#   https://music.apple.com/in/song/673594504
#   https://music.apple.com/in/song/673594507
#   https://music.apple.com/in/song/673594550
#   https://music.apple.com/in/song/673594553
#   https://music.apple.com/in/song/673594556
#   https://music.apple.com/in/song/673594557
#   https://music.apple.com/in/song/673594560
#   https://music.apple.com/in/song/673594563
# Nee Manasu Naaku Telusu (Original Motion Picture Soundtrack) (2003):
#   https://music.apple.com/in/song/928892058
#   https://music.apple.com/in/song/928892065
#   https://music.apple.com/in/song/928892066
#   https://music.apple.com/in/song/928892067
#   https://music.apple.com/in/song/928892073
#   https://music.apple.com/in/song/928892076
# Boys (Original Motion Picture Soundtrack) (2003):
#   https://music.apple.com/in/song/928328217
#   https://music.apple.com/in/song/928328221
#   https://music.apple.com/in/song/928328222
#   https://music.apple.com/in/song/928328223
#   https://music.apple.com/in/song/928328228
#   https://music.apple.com/in/song/928328230
# Boys (Orignal Motion Picture Soundtrack) (2003):
#   https://music.apple.com/in/song/946183022
#   https://music.apple.com/in/song/946183023
#   https://music.apple.com/in/song/946183031
#   https://music.apple.com/in/song/946183032
#   https://music.apple.com/in/song/946183039
#   https://music.apple.com/in/song/946183041
#   https://music.apple.com/in/song/946183043
# Nani (Original Motion Picture Soundtrack) (2004):
#   https://music.apple.com/in/song/931701796
#   https://music.apple.com/in/song/931701800
#   https://music.apple.com/in/song/931701802
#   https://music.apple.com/in/song/931701810
#   https://music.apple.com/in/song/931701812
#   https://music.apple.com/in/song/931701816
#   https://music.apple.com/in/song/931701817
# Aayitha Ezhutu (Original Motion Picture Soundtrack) (2004):
#   https://music.apple.com/in/song/212249990
#   https://music.apple.com/in/song/212250028
#   https://music.apple.com/in/song/212250042
#   https://music.apple.com/in/song/212250092
#   https://music.apple.com/in/song/212250097
#   https://music.apple.com/in/song/212250120
# Yuva (Original Motion Picture Soundtrack) (2004):
#   https://music.apple.com/in/song/1126828778
#   https://music.apple.com/in/song/1126829181
#   https://music.apple.com/in/song/1126829184
#   https://music.apple.com/in/song/1126829189
#   https://music.apple.com/in/song/1126829192
#   https://music.apple.com/in/song/1126829389
# Yuva (Original Motion Picture Soundtrack) (2004):
#   https://music.apple.com/in/song/931702284
#   https://music.apple.com/in/song/931702287
#   https://music.apple.com/in/song/931702295
#   https://music.apple.com/in/song/931702303
#   https://music.apple.com/in/song/931702339
#   https://music.apple.com/in/song/931702341
# Meenaxi (Original Motion Picture Soundtrack) (2004):
#   https://music.apple.com/in/song/302391748
#   https://music.apple.com/in/song/302391749
#   https://music.apple.com/in/song/302391750
#   https://music.apple.com/in/song/302391755
#   https://music.apple.com/in/song/302391757
#   https://music.apple.com/in/song/302391758
#   https://music.apple.com/in/song/302391763
#   https://music.apple.com/in/song/302391771
# Between Heaven and Earth (2004):
#   https://music.apple.com/in/song/193893678
#   https://music.apple.com/in/song/193893746
#   https://music.apple.com/in/song/193893801
#   https://music.apple.com/in/song/193893916
#   https://music.apple.com/in/song/193894230
#   https://music.apple.com/in/song/193894332
#   https://music.apple.com/in/song/193894403
#   https://music.apple.com/in/song/193894410
#   https://music.apple.com/in/song/193894415
#   https://music.apple.com/in/song/193894423
#   https://music.apple.com/in/song/193894428
#   https://music.apple.com/in/song/193894481
#   https://music.apple.com/in/song/193894628
#   https://music.apple.com/in/song/193894645
#   https://music.apple.com/in/song/193894978
# New (Original Motion Picture Soundtrack) (2004):
#   https://music.apple.com/in/song/686953916
#   https://music.apple.com/in/song/686953917
#   https://music.apple.com/in/song/686953921
#   https://music.apple.com/in/song/686953922
#   https://music.apple.com/in/song/686953926
#   https://music.apple.com/in/song/686953927
#   https://music.apple.com/in/song/686953950
# Swades (Original Motion Picture Soundtrack) (2004):
#   https://music.apple.com/in/song/1120951283
#   https://music.apple.com/in/song/1120951295
#   https://music.apple.com/in/song/1120951296
#   https://music.apple.com/in/song/1120951317
#   https://music.apple.com/in/song/1120951318
#   https://music.apple.com/in/song/1120951319
#   https://music.apple.com/in/song/1120951323
#   https://music.apple.com/in/song/1120951324
#   https://music.apple.com/in/song/1120951325
# Bose the Forgotten Hero (Original Motion Picture Soundtrack) (2005):
#   https://music.apple.com/in/song/131276852
#   https://music.apple.com/in/song/131276914
#   https://music.apple.com/in/song/131276943
#   https://music.apple.com/in/song/131276964
#   https://music.apple.com/in/song/131276982
#   https://music.apple.com/in/song/131277000
#   https://music.apple.com/in/song/131277080
#   https://music.apple.com/in/song/131277131
#   https://music.apple.com/in/song/131277182
#   https://music.apple.com/in/song/131277195
#   https://music.apple.com/in/song/131277218
#   https://music.apple.com/in/song/131277223
#   https://music.apple.com/in/song/131277235
#   https://music.apple.com/in/song/131277278
#   https://music.apple.com/in/song/131277306
#   https://music.apple.com/in/song/131277346
#   https://music.apple.com/in/song/131277353
#   https://music.apple.com/in/song/131277456
#   https://music.apple.com/in/song/131277489
#   https://music.apple.com/in/song/131277519
# Rang De Basanti (Original Motion Picture Soundtrack) (2005):
#   https://music.apple.com/in/song/316981879
#   https://music.apple.com/in/song/316981880
#   https://music.apple.com/in/song/316981881
#   https://music.apple.com/in/song/316981883
#   https://music.apple.com/in/song/316981885
#   https://music.apple.com/in/song/316981886
#   https://music.apple.com/in/song/316981888
#   https://music.apple.com/in/song/316981890
#   https://music.apple.com/in/song/316981893
#   https://music.apple.com/in/song/316981894
# Nuvvu Nenu Prema (Original Motion Picture Soundtrack) (2006):
#   https://music.apple.com/in/song/930722937
#   https://music.apple.com/in/song/930722943
#   https://music.apple.com/in/song/930722951
#   https://music.apple.com/in/song/930722956
#   https://music.apple.com/in/song/930722958
#   https://music.apple.com/in/song/930722961
#   https://music.apple.com/in/song/930722964
# Godfather (Original Motion Picture Soundtrack) (2006):
#   https://music.apple.com/in/song/951407296
#   https://music.apple.com/in/song/951407297
#   https://music.apple.com/in/song/951407298
#   https://music.apple.com/in/song/951407299
#   https://music.apple.com/in/song/951407300
#   https://music.apple.com/in/song/951407301
#   https://music.apple.com/in/song/951407302
#   https://music.apple.com/in/song/951407303
# Guru (Original Motion Picture Soundtrack) (2006):
#   https://music.apple.com/in/song/264849909
#   https://music.apple.com/in/song/264849919
#   https://music.apple.com/in/song/264849945
#   https://music.apple.com/in/song/264849964
#   https://music.apple.com/in/song/264849994
#   https://music.apple.com/in/song/264850115
#   https://music.apple.com/in/song/264850141
# Pray for Me Brother - Single (2007):
#   https://music.apple.com/in/song/1444055238
#   https://music.apple.com/in/song/1444055254
# Guru (Original Motion Picture Soundtrack) [Tamil Version] (2007):
#   https://music.apple.com/in/song/275805968
#   https://music.apple.com/in/song/275805972
#   https://music.apple.com/in/song/275805976
#   https://music.apple.com/in/song/275805980
#   https://music.apple.com/in/song/275805984
#   https://music.apple.com/in/song/275805988
#   https://music.apple.com/in/song/275805992
# Azagiya Tamilmagan (Original Motion Picture Soundtrack) (2007):
#   https://music.apple.com/in/song/561074892
#   https://music.apple.com/in/song/561074893
#   https://music.apple.com/in/song/561074899
#   https://music.apple.com/in/song/561074903
#   https://music.apple.com/in/song/561074904
#   https://music.apple.com/in/song/561074905
# Jodhaa Akbar (Original Motion Picture Soundtrack) (2007):
#   https://music.apple.com/in/song/1537961310
#   https://music.apple.com/in/song/1537961312
#   https://music.apple.com/in/song/1537961313
#   https://music.apple.com/in/song/1537961314
#   https://music.apple.com/in/song/1537961315
#   https://music.apple.com/in/song/1537961587
#   https://music.apple.com/in/song/1537961589
# The Lord of the Rings (Original London Production) (2008):
#   https://music.apple.com/in/song/274086094
#   https://music.apple.com/in/song/274086128
#   https://music.apple.com/in/song/274086143
#   https://music.apple.com/in/song/274086186
#   https://music.apple.com/in/song/274086193
#   https://music.apple.com/in/song/274086195
#   https://music.apple.com/in/song/274086227
#   https://music.apple.com/in/song/274086228
#   https://music.apple.com/in/song/274086238
#   https://music.apple.com/in/song/274086249
#   https://music.apple.com/in/song/274086335
#   https://music.apple.com/in/song/274086340
#   https://music.apple.com/in/song/274086348
#   https://music.apple.com/in/song/274086349
#   https://music.apple.com/in/song/274086355
#   https://music.apple.com/in/song/274086362
#   https://music.apple.com/in/song/274086398
#   https://music.apple.com/in/song/274086410
# Jaane Tu... Ya Jaane Na (Original Motion Picture Soundtrack) (2008):
#   https://music.apple.com/in/song/1121136870
#   https://music.apple.com/in/song/1121136876
#   https://music.apple.com/in/song/1121136888
#   https://music.apple.com/in/song/1121136889
#   https://music.apple.com/in/song/1121136900
#   https://music.apple.com/in/song/1121136901
#   https://music.apple.com/in/song/1121136902
#   https://music.apple.com/in/song/1121136903
# Sakkarakatti (Original Motion Picture Soundtrack) (2008):
#   https://music.apple.com/in/song/303019305
#   https://music.apple.com/in/song/303019313
#   https://music.apple.com/in/song/303019319
#   https://music.apple.com/in/song/303019328
#   https://music.apple.com/in/song/303019416
#   https://music.apple.com/in/song/303019434
# Ghajini (Original Motion Picture Soundtrack) (2008):
#   https://music.apple.com/in/song/1133344521
#   https://music.apple.com/in/song/1133344522
#   https://music.apple.com/in/song/1133344523
#   https://music.apple.com/in/song/1133344524
#   https://music.apple.com/in/song/1133344528
#   https://music.apple.com/in/song/1133344530
# Slumdog Millionaire (Original Motion Picture Soundtrack) (2009):
#   https://music.apple.com/in/song/1358474689
#   https://music.apple.com/in/song/1358474690
#   https://music.apple.com/in/song/1358474691
#   https://music.apple.com/in/song/1358474695
#   https://music.apple.com/in/song/1358474696
#   https://music.apple.com/in/song/1358474702
#   https://music.apple.com/in/song/1358474705
#   https://music.apple.com/in/song/1358474706
#   https://music.apple.com/in/song/1358474707
#   https://music.apple.com/in/song/1358474708
# Delhi-6 (Original Motion Picture Soundtrack) (2009):
#   https://music.apple.com/in/song/1131692109
#   https://music.apple.com/in/song/1131692110
#   https://music.apple.com/in/song/1131692261
#   https://music.apple.com/in/song/1131692263
#   https://music.apple.com/in/song/1131692270
#   https://music.apple.com/in/song/1131692271
#   https://music.apple.com/in/song/1131692273
#   https://music.apple.com/in/song/1131692274
#   https://music.apple.com/in/song/1131692276
#   https://music.apple.com/in/song/1131692279
# The Best of A. R. Rahman - Music and Magic from the Composer of Slumdog Millionaire (2009):
#   https://music.apple.com/in/song/305196795
#   https://music.apple.com/in/song/305196827
#   https://music.apple.com/in/song/305196830
#   https://music.apple.com/in/song/305196832
#   https://music.apple.com/in/song/305196834
#   https://music.apple.com/in/song/305196837
#   https://music.apple.com/in/song/305196839
#   https://music.apple.com/in/song/305196846
#   https://music.apple.com/in/song/305196848
#   https://music.apple.com/in/song/305196850
#   https://music.apple.com/in/song/305196852
#   https://music.apple.com/in/song/305196855
#   https://music.apple.com/in/song/305196858
# Blue (Original Motion Picture Soundtrack) (2009):
#   https://music.apple.com/in/song/1130971735
#   https://music.apple.com/in/song/1130971739
#   https://music.apple.com/in/song/1130971741
#   https://music.apple.com/in/song/1130971742
#   https://music.apple.com/in/song/1130971743
#   https://music.apple.com/in/song/1130971753
#   https://music.apple.com/in/song/1130971756
# Sivaji The Boss (Original Motion Picture Soundtrack) (2010):
#   https://music.apple.com/in/song/349925106
#   https://music.apple.com/in/song/349925107
#   https://music.apple.com/in/song/349925108
#   https://music.apple.com/in/song/349925111
#   https://music.apple.com/in/song/349925115
#   https://music.apple.com/in/song/349925146
#   https://music.apple.com/in/song/349925156
# Vinnaithaandi Varuvaayaa (Original Motion Picture Soundtrack) (2010):
#   https://music.apple.com/in/song/349285473
#   https://music.apple.com/in/song/349285474
#   https://music.apple.com/in/song/349285475
#   https://music.apple.com/in/song/349285476
#   https://music.apple.com/in/song/349285477
#   https://music.apple.com/in/song/349285478
#   https://music.apple.com/in/song/349285479
# Yemaaya Chesave (Original Motion Picture Soundtrack) (2010):
#   https://music.apple.com/in/song/352317852
#   https://music.apple.com/in/song/352317853
#   https://music.apple.com/in/song/352317857
#   https://music.apple.com/in/song/352317861
#   https://music.apple.com/in/song/352317864
#   https://music.apple.com/in/song/352317865
#   https://music.apple.com/in/song/352317866
# Raavan (Original Motion Picture Soundtrack) (2010):
#   https://music.apple.com/in/song/1129369654
#   https://music.apple.com/in/song/1129369659
#   https://music.apple.com/in/song/1129369660
#   https://music.apple.com/in/song/1129369664
#   https://music.apple.com/in/song/1129369667
#   https://music.apple.com/in/song/1129369671
# Raavanan (Original Motion Picture Soundtrack) (2010):
#   https://music.apple.com/in/song/400323692
#   https://music.apple.com/in/song/400323968
#   https://music.apple.com/in/song/400324232
#   https://music.apple.com/in/song/400324249
#   https://music.apple.com/in/song/400324255
#   https://music.apple.com/in/song/400324547
#   https://music.apple.com/in/song/400324972
#   https://music.apple.com/in/song/400325008
#   https://music.apple.com/in/song/400325074
#   https://music.apple.com/in/song/400325127
#   https://music.apple.com/in/song/400325129
# Villain (Original Soundtrack) (2010):
#   https://music.apple.com/in/song/372672187
#   https://music.apple.com/in/song/372672195
#   https://music.apple.com/in/song/372672208
#   https://music.apple.com/in/song/372672212
#   https://music.apple.com/in/song/372672216
#   https://music.apple.com/in/song/372672226
# Komaram Puli (Original Motion Picture Soundtrack) (2010):
#   https://music.apple.com/in/song/381095185
#   https://music.apple.com/in/song/381095194
#   https://music.apple.com/in/song/381095204
#   https://music.apple.com/in/song/381095214
#   https://music.apple.com/in/song/381095234
#   https://music.apple.com/in/song/381095362
# Enthiran (Original Motion Picture Soundtrack) (2010):
#   https://music.apple.com/in/song/1108797413
#   https://music.apple.com/in/song/1108797422
#   https://music.apple.com/in/song/1108797429
#   https://music.apple.com/in/song/1108797527
#   https://music.apple.com/in/song/1108797531
#   https://music.apple.com/in/song/1108797563
#   https://music.apple.com/in/song/1108797565
# Robot (Original Motion Picture Soundtrack) (2010):
#   https://music.apple.com/in/song/1241865622
#   https://music.apple.com/in/song/1241865626
#   https://music.apple.com/in/song/1241865627
#   https://music.apple.com/in/song/1241865628
#   https://music.apple.com/in/song/1241865629
#   https://music.apple.com/in/song/1241865630
#   https://music.apple.com/in/song/1241865631
# Rockstar (Original Motion Picture Soundtrack) (2011):
#   https://music.apple.com/in/song/1123241858
#   https://music.apple.com/in/song/1123241859
#   https://music.apple.com/in/song/1123241860
#   https://music.apple.com/in/song/1123241921
#   https://music.apple.com/in/song/1123241922
#   https://music.apple.com/in/song/1123241923
#   https://music.apple.com/in/song/1123241924
#   https://music.apple.com/in/song/1123241925
#   https://music.apple.com/in/song/1123241926
#   https://music.apple.com/in/song/1123241927
#   https://music.apple.com/in/song/1123241928
#   https://music.apple.com/in/song/1123241929
#   https://music.apple.com/in/song/1123241930
#   https://music.apple.com/in/song/1123241931
# Ekk Deewana Tha (Original Motion Picture Soundtrack) (2011):
#   https://music.apple.com/in/song/492685700
#   https://music.apple.com/in/song/492685701
#   https://music.apple.com/in/song/492685704
#   https://music.apple.com/in/song/492685712
#   https://music.apple.com/in/song/492685717
#   https://music.apple.com/in/song/492685718
#   https://music.apple.com/in/song/492685720
#   https://music.apple.com/in/song/492685721
#   https://music.apple.com/in/song/492685722
#   https://music.apple.com/in/song/492685723
#   https://music.apple.com/in/song/492685724
#   https://music.apple.com/in/song/492685725
# Jab Tak Hai Jaan (Original Soundtrack) (2012):
#   https://music.apple.com/in/song/673998971
#   https://music.apple.com/in/song/673998975
#   https://music.apple.com/in/song/673998979
#   https://music.apple.com/in/song/673998984
#   https://music.apple.com/in/song/673998988
#   https://music.apple.com/in/song/673999053
#   https://music.apple.com/in/song/673999057
#   https://music.apple.com/in/song/673999081
#   https://music.apple.com/in/song/673999087
# Nenjukkule (feat. Shakthisree Gopalan) [From "Kadal"] - Single (2012):
#   https://music.apple.com/in/song/583892764
# Elay Keechan (From "Kadal") - Single (2012):
#   https://music.apple.com/in/song/584893296
# Kadal (Original Motion Picture Soundtrack) (2012):
#   https://music.apple.com/in/song/585714008
#   https://music.apple.com/in/song/585714012
#   https://music.apple.com/in/song/585714019
#   https://music.apple.com/in/song/585714026
#   https://music.apple.com/in/song/585714027
#   https://music.apple.com/in/song/585714029
#   https://music.apple.com/in/song/585714036
# Kadali (Original Motion Picture Soundtrack) (2012):
#   https://music.apple.com/in/song/589552710
#   https://music.apple.com/in/song/589552713
#   https://music.apple.com/in/song/589552714
#   https://music.apple.com/in/song/589552716
#   https://music.apple.com/in/song/589552717
#   https://music.apple.com/in/song/589552718
#   https://music.apple.com/in/song/589552749
# A. R. Rahman Vibration (2013):
#   https://music.apple.com/in/song/599324661
#   https://music.apple.com/in/song/599324662
#   https://music.apple.com/in/song/599324663
#   https://music.apple.com/in/song/599324833
#   https://music.apple.com/in/song/599324836
#   https://music.apple.com/in/song/599324837
#   https://music.apple.com/in/song/599324840
#   https://music.apple.com/in/song/599324848
#   https://music.apple.com/in/song/599324849
#   https://music.apple.com/in/song/599324850
#   https://music.apple.com/in/song/599324856
#   https://music.apple.com/in/song/599324857
#   https://music.apple.com/in/song/599324858
#   https://music.apple.com/in/song/599324861
#   https://music.apple.com/in/song/599324865
#   https://music.apple.com/in/song/599324866
#   https://music.apple.com/in/song/599324867
#   https://music.apple.com/in/song/599324874
#   https://music.apple.com/in/song/599324875
#   https://music.apple.com/in/song/599324876
# Infinite Love (K-Kov Remix) - Single (2013):
#   https://music.apple.com/in/song/604969053
# Nenjae Yezhu (From "Maryan") - Single (2013):
#   https://music.apple.com/in/song/642338830
# Maryan (Original Motion Picture Soundtrack) (2013):
#   https://music.apple.com/in/song/646630023
#   https://music.apple.com/in/song/646630025
#   https://music.apple.com/in/song/646630027
#   https://music.apple.com/in/song/646630030
#   https://music.apple.com/in/song/646630035
#   https://music.apple.com/in/song/646630038
#   https://music.apple.com/in/song/646630044
# Tum Tak (From "Raanjhanaa") - Single (2013):
#   https://music.apple.com/in/song/652094580
# Raanjhanaa (From "Raanjhanaa") - Single (2013):
#   https://music.apple.com/in/song/652698649
# Raanjhanaa (Original Motion Picture Soundtrack) (2013):
#   https://music.apple.com/in/song/656015921
#   https://music.apple.com/in/song/656015922
#   https://music.apple.com/in/song/656015923
#   https://music.apple.com/in/song/656015927
#   https://music.apple.com/in/song/656016011
#   https://music.apple.com/in/song/656016012
#   https://music.apple.com/in/song/656016089
#   https://music.apple.com/in/song/656016090
#   https://music.apple.com/in/song/656016091
# Ambikapathy (Original Motion Picture Soundtrack) (2013):
#   https://music.apple.com/in/song/662043656
#   https://music.apple.com/in/song/662043657
#   https://music.apple.com/in/song/662043659
#   https://music.apple.com/in/song/662043661
#   https://music.apple.com/in/song/662043665
#   https://music.apple.com/in/song/662043666
#   https://music.apple.com/in/song/662043667
#   https://music.apple.com/in/song/662043668
#   https://music.apple.com/in/song/662043689
# Piya Milenge (2013):
#   https://music.apple.com/in/song/669377480
#   https://music.apple.com/in/song/669377481
#   https://music.apple.com/in/song/669377482
#   https://music.apple.com/in/song/669377483
#   https://music.apple.com/in/song/669377484
#   https://music.apple.com/in/song/669377485
#   https://music.apple.com/in/song/669377486
#   https://music.apple.com/in/song/669377487
#   https://music.apple.com/in/song/669377488
#   https://music.apple.com/in/song/669377549
#   https://music.apple.com/in/song/669377550
#   https://music.apple.com/in/song/669377554
# Voice of Rahman (2013):
#   https://music.apple.com/in/song/669468064
#   https://music.apple.com/in/song/669468065
#   https://music.apple.com/in/song/669468067
#   https://music.apple.com/in/song/669468068
#   https://music.apple.com/in/song/669468069
#   https://music.apple.com/in/song/669468070
#   https://music.apple.com/in/song/669468071
#   https://music.apple.com/in/song/669468073
#   https://music.apple.com/in/song/669468074
#   https://music.apple.com/in/song/669468075
# Hits Penned By Gulzar (2013):
#   https://music.apple.com/in/song/687676724
#   https://music.apple.com/in/song/687676725
#   https://music.apple.com/in/song/687676726
#   https://music.apple.com/in/song/687676727
#   https://music.apple.com/in/song/687676728
#   https://music.apple.com/in/song/687676869
#   https://music.apple.com/in/song/687676870
#   https://music.apple.com/in/song/687676871
# Coke Studio @ MTV Season 3: Episode 1 (2013):
#   https://music.apple.com/in/song/687676249
#   https://music.apple.com/in/song/687676257
#   https://music.apple.com/in/song/687676260
#   https://music.apple.com/in/song/687676278
#   https://music.apple.com/in/song/687676282
#   https://music.apple.com/in/song/687676285
# Engae Pogudho Vaanam (From "Kochadaiiyaan") - Single (2013):
#   https://music.apple.com/in/song/717095067
# Choodham Aakasam Antham (From "Vikramasimha") - Single (2013):
#   https://music.apple.com/in/song/717095536
# Hits of A.R.Rahman Nenjame (2013):
#   https://music.apple.com/in/song/812959014
#   https://music.apple.com/in/song/812959015
#   https://music.apple.com/in/song/812959018
#   https://music.apple.com/in/song/812959019
#   https://music.apple.com/in/song/812959020
#   https://music.apple.com/in/song/812959021
#   https://music.apple.com/in/song/812959022
#   https://music.apple.com/in/song/812959024
#   https://music.apple.com/in/song/812959026
#   https://music.apple.com/in/song/812959027
#   https://music.apple.com/in/song/812959032
#   https://music.apple.com/in/song/812959033
#   https://music.apple.com/in/song/812959034
#   https://music.apple.com/in/song/812959035
#   https://music.apple.com/in/song/812959038
# Hits of A.R.Rahman - Isai Saral (2013):
#   https://music.apple.com/in/song/813911680
#   https://music.apple.com/in/song/813911681
#   https://music.apple.com/in/song/813911683
#   https://music.apple.com/in/song/813911684
#   https://music.apple.com/in/song/813911689
#   https://music.apple.com/in/song/813911690
#   https://music.apple.com/in/song/813911691
#   https://music.apple.com/in/song/813911696
#   https://music.apple.com/in/song/813911697
#   https://music.apple.com/in/song/813911698
#   https://music.apple.com/in/song/813911699
#   https://music.apple.com/in/song/813911700
#   https://music.apple.com/in/song/813911701
#   https://music.apple.com/in/song/813911702
#   https://music.apple.com/in/song/813911703
# Biggest Hits of Rahman (2014):
#   https://music.apple.com/in/song/784433914
#   https://music.apple.com/in/song/784433915
#   https://music.apple.com/in/song/784433916
#   https://music.apple.com/in/song/784433917
#   https://music.apple.com/in/song/784433918
#   https://music.apple.com/in/song/784433919
#   https://music.apple.com/in/song/784433920
#   https://music.apple.com/in/song/784433921
#   https://music.apple.com/in/song/784433922
#   https://music.apple.com/in/song/784433923
#   https://music.apple.com/in/song/784433924
#   https://music.apple.com/in/song/784433925
#   https://music.apple.com/in/song/784433926
#   https://music.apple.com/in/song/784433927
# Highway (Original Motion Picture Soundtrack) (2014):
#   https://music.apple.com/in/song/1116181291
#   https://music.apple.com/in/song/1116181297
#   https://music.apple.com/in/song/1116181298
#   https://music.apple.com/in/song/1116181299
#   https://music.apple.com/in/song/1116181309
#   https://music.apple.com/in/song/1116181313
#   https://music.apple.com/in/song/1116181314
#   https://music.apple.com/in/song/1116181315
#   https://music.apple.com/in/song/1116181316
# Kismat Se (From "Raunaq") - Single (2014):
#   https://music.apple.com/in/song/826281066
# Kochadaiiyaan (Original Motion Picture Soundtrack) (2014):
#   https://music.apple.com/in/song/828908305
#   https://music.apple.com/in/song/828908307
#   https://music.apple.com/in/song/828908308
#   https://music.apple.com/in/song/828908313
#   https://music.apple.com/in/song/828908316
#   https://music.apple.com/in/song/828908317
#   https://music.apple.com/in/song/828908321
#   https://music.apple.com/in/song/828908322
#   https://music.apple.com/in/song/828908326
# Vikramasimha (Original Motion Picture Soundtrack) (2014):
#   https://music.apple.com/in/song/828945895
#   https://music.apple.com/in/song/828945896
#   https://music.apple.com/in/song/828945898
#   https://music.apple.com/in/song/828945900
#   https://music.apple.com/in/song/828945901
#   https://music.apple.com/in/song/828945902
#   https://music.apple.com/in/song/828945906
#   https://music.apple.com/in/song/828945908
#   https://music.apple.com/in/song/828945909
# Aabhi Jaa (From "Raunaq") - Single (2014):
#   https://music.apple.com/in/song/839371884
# Vaanga Makka Vaanga (From "Kaaviyathalaivan") - Single (2014):
#   https://music.apple.com/in/song/896194636
# Yaarumilla (From "Kaaviyathalaivan") - Single (2014):
#   https://music.apple.com/in/song/906613410
# A. R. Rahman - Voice of a Nation (2014):
#   https://music.apple.com/in/song/904957533
#   https://music.apple.com/in/song/904957534
#   https://music.apple.com/in/song/904957535
#   https://music.apple.com/in/song/904957536
#   https://music.apple.com/in/song/904957539
#   https://music.apple.com/in/song/904957540
#   https://music.apple.com/in/song/904957541
#   https://music.apple.com/in/song/904957542
#   https://music.apple.com/in/song/904957543
#   https://music.apple.com/in/song/904957544
#   https://music.apple.com/in/song/904957545
#   https://music.apple.com/in/song/904957546
#   https://music.apple.com/in/song/904957547
#   https://music.apple.com/in/song/904957548
# Kaaviyathalaivan (Original Motion Picture Soundtrack) (2014):
#   https://music.apple.com/in/song/908588168
#   https://music.apple.com/in/song/908588169
#   https://music.apple.com/in/song/908588172
#   https://music.apple.com/in/song/908588174
#   https://music.apple.com/in/song/908588187
#   https://music.apple.com/in/song/908588196
#   https://music.apple.com/in/song/908588201
# I (Original Motion Picture Soundtrack) (2014):
#   https://music.apple.com/in/song/917639895
#   https://music.apple.com/in/song/917639897
#   https://music.apple.com/in/song/917639898
#   https://music.apple.com/in/song/917639902
#   https://music.apple.com/in/song/917639903
#   https://music.apple.com/in/song/917639904
#   https://music.apple.com/in/song/917639905
# Raunaq (2014):
#   https://music.apple.com/in/song/921556824
#   https://music.apple.com/in/song/921556826
#   https://music.apple.com/in/song/921556827
#   https://music.apple.com/in/song/921556828
#   https://music.apple.com/in/song/921556830
#   https://music.apple.com/in/song/921556831
#   https://music.apple.com/in/song/921556832
# Big FM Rahman Ungaludan (2014):
#   https://music.apple.com/in/song/929578210
#   https://music.apple.com/in/song/929578211
#   https://music.apple.com/in/song/929578214
#   https://music.apple.com/in/song/929578216
#   https://music.apple.com/in/song/929578217
#   https://music.apple.com/in/song/929578219
#   https://music.apple.com/in/song/929578224
#   https://music.apple.com/in/song/929578225
#   https://music.apple.com/in/song/929578226
#   https://music.apple.com/in/song/929578231
#   https://music.apple.com/in/song/929578232
#   https://music.apple.com/in/song/929578233
#   https://music.apple.com/in/song/929578236
#   https://music.apple.com/in/song/929578244
#   https://music.apple.com/in/song/929578245
#   https://music.apple.com/in/song/929578246
#   https://music.apple.com/in/song/929578247
#   https://music.apple.com/in/song/929578249
#   https://music.apple.com/in/song/929578253
#   https://music.apple.com/in/song/929578254
#   https://music.apple.com/in/song/929578256
#   https://music.apple.com/in/song/929578257
#   https://music.apple.com/in/song/929578259
#   https://music.apple.com/in/song/929578260
#   https://music.apple.com/in/song/929578262
#   https://music.apple.com/in/song/929578263
#   https://music.apple.com/in/song/929578265
#   https://music.apple.com/in/song/929578268
#   https://music.apple.com/in/song/929578274
#   https://music.apple.com/in/song/929578275
#   https://music.apple.com/in/song/929578277
#   https://music.apple.com/in/song/929578278
#   https://music.apple.com/in/song/929578279
#   https://music.apple.com/in/song/929578280
#   https://music.apple.com/in/song/929578281
#   https://music.apple.com/in/song/929578283
#   https://music.apple.com/in/song/929578286
#   https://music.apple.com/in/song/929578288
#   https://music.apple.com/in/song/929578289
#   https://music.apple.com/in/song/929578290
#   https://music.apple.com/in/song/929578291
#   https://music.apple.com/in/song/929578292
#   https://music.apple.com/in/song/929578294
#   https://music.apple.com/in/song/929578295
#   https://music.apple.com/in/song/929578297
# Jab Tak Hai Jaan - Mashup - Single (2014):
#   https://music.apple.com/in/song/955416505
# I - Manoharudu (Original Motion Picture Soundtrack) (2014):
#   https://music.apple.com/in/song/953411599
#   https://music.apple.com/in/song/953411600
#   https://music.apple.com/in/song/953411604
#   https://music.apple.com/in/song/953411605
#   https://music.apple.com/in/song/953411606
#   https://music.apple.com/in/song/953411607
#   https://music.apple.com/in/song/953411608
# Mental Manadhil (From "O Kadhal Kanmani") - Single (2015):
#   https://music.apple.com/in/song/975869251
# Mental Madhilo (From "OK Bangaram") - Single (2015):
#   https://music.apple.com/in/song/976019917
# Rediscovered Gems: A.R. Rahman (2015):
#   https://music.apple.com/in/song/975858555
#   https://music.apple.com/in/song/975858556
#   https://music.apple.com/in/song/975858557
#   https://music.apple.com/in/song/975858558
#   https://music.apple.com/in/song/975858560
#   https://music.apple.com/in/song/975858741
#   https://music.apple.com/in/song/975858742
#   https://music.apple.com/in/song/975858743
# O Kadhal Kanmani (Original Motion Picture Soundtrack) (2015):
#   https://music.apple.com/in/song/980176946
#   https://music.apple.com/in/song/980176949
#   https://music.apple.com/in/song/980176950
#   https://music.apple.com/in/song/980176951
#   https://music.apple.com/in/song/980176952
#   https://music.apple.com/in/song/980176953
#   https://music.apple.com/in/song/980176954
#   https://music.apple.com/in/song/980177315
#   https://music.apple.com/in/song/980177316
# OK Bangaram (Original Motion Picture Soundtrack) (2015):
#   https://music.apple.com/in/song/980179179
#   https://music.apple.com/in/song/980179180
#   https://music.apple.com/in/song/980179181
#   https://music.apple.com/in/song/980179182
#   https://music.apple.com/in/song/980179183
#   https://music.apple.com/in/song/980179184
#   https://music.apple.com/in/song/980179185
#   https://music.apple.com/in/song/980179186
#   https://music.apple.com/in/song/980179187
# Mariyaan (Original Motion Picture Soundtrack) (2015):
#   https://music.apple.com/in/song/1002867816
#   https://music.apple.com/in/song/1002867817
#   https://music.apple.com/in/song/1002867820
#   https://music.apple.com/in/song/1002867821
#   https://music.apple.com/in/song/1002867822
#   https://music.apple.com/in/song/1002867824
#   https://music.apple.com/in/song/1002867825
# Tamasha (Original Motion Picture Soundtrack) (2015):
#   https://music.apple.com/in/song/1071074554
#   https://music.apple.com/in/song/1071074555
#   https://music.apple.com/in/song/1071074558
#   https://music.apple.com/in/song/1071074681
#   https://music.apple.com/in/song/1071074684
#   https://music.apple.com/in/song/1071074691
#   https://music.apple.com/in/song/1071074694
#   https://music.apple.com/in/song/1071074697
#   https://music.apple.com/in/song/1071074704
# Chakkori (From "Sahasam Swasaga Sagipo") - Single (2016):
#   https://music.apple.com/in/song/1117756806
# Vellipomaakey (From "Sahasam Swasaga Sagipo") - Single (2016):
#   https://music.apple.com/in/song/1123149652
# Saahasam Swaasaga Saagipo (Original Motion Picture Soundtrack) (2016):
#   https://music.apple.com/in/song/1123522398
#   https://music.apple.com/in/song/1123522410
#   https://music.apple.com/in/song/1123522412
#   https://music.apple.com/in/song/1123522419
#   https://music.apple.com/in/song/1123522487
# Pelé (Original Motion Picture Soundtrack) (2016):
#   https://music.apple.com/in/song/1120563298
#   https://music.apple.com/in/song/1120563301
#   https://music.apple.com/in/song/1120563308
#   https://music.apple.com/in/song/1120563309
#   https://music.apple.com/in/song/1120563310
#   https://music.apple.com/in/song/1120563344
#   https://music.apple.com/in/song/1120563345
#   https://music.apple.com/in/song/1120563346
#   https://music.apple.com/in/song/1120563350
#   https://music.apple.com/in/song/1120563351
#   https://music.apple.com/in/song/1120563354
#   https://music.apple.com/in/song/1120563356
#   https://music.apple.com/in/song/1120563357
#   https://music.apple.com/in/song/1120563358
#   https://music.apple.com/in/song/1120563359
#   https://music.apple.com/in/song/1120563361
#   https://music.apple.com/in/song/1120563362
#   https://music.apple.com/in/song/1120563366
#   https://music.apple.com/in/song/1120563369
#   https://music.apple.com/in/song/1120563372
# Mohenjo Daro (Original Motion Picture Soundtrack) (2016):
#   https://music.apple.com/in/song/1159724664
#   https://music.apple.com/in/song/1159724674
#   https://music.apple.com/in/song/1159724676
#   https://music.apple.com/in/song/1159724682
#   https://music.apple.com/in/song/1159724683
#   https://music.apple.com/in/song/1159724684
#   https://music.apple.com/in/song/1159724691
#   https://music.apple.com/in/song/1159724707
# Futsal Anthem (feat. Virat Kohli) - Single (2016):
#   https://music.apple.com/in/song/1132124340
# OK Jaanu Title Track - Single (2016):
# The Humma Song (From "OK Jaanu") - Single (2016):
# Enna Sona (From "OK Jaanu") - Single (2016):
# OK Jaanu (Original Motion Picture Soundtrack) (2017):
#   https://music.apple.com/in/song/1189133563
#   https://music.apple.com/in/song/1189133564
#   https://music.apple.com/in/song/1189133567
#   https://music.apple.com/in/song/1189133573
#   https://music.apple.com/in/song/1189133598
#   https://music.apple.com/in/song/1189133600
#   https://music.apple.com/in/song/1189134856
#   https://music.apple.com/in/song/1189134857
# Timeless at 50 : A.R. Rahman, Vol. 1 (2017):
#   https://music.apple.com/in/song/1188684547
#   https://music.apple.com/in/song/1188684548
#   https://music.apple.com/in/song/1188684549
#   https://music.apple.com/in/song/1188684641
#   https://music.apple.com/in/song/1188684647
#   https://music.apple.com/in/song/1188684649
#   https://music.apple.com/in/song/1188684650
#   https://music.apple.com/in/song/1188684651
#   https://music.apple.com/in/song/1188684652
#   https://music.apple.com/in/song/1188684663
#   https://music.apple.com/in/song/1188684664
#   https://music.apple.com/in/song/1188684665
#   https://music.apple.com/in/song/1188684666
#   https://music.apple.com/in/song/1188684668
#   https://music.apple.com/in/song/1188684669
#   https://music.apple.com/in/song/1188684824
#   https://music.apple.com/in/song/1188684825
#   https://music.apple.com/in/song/1188684826
#   https://music.apple.com/in/song/1188684827
#   https://music.apple.com/in/song/1188684828
#   https://music.apple.com/in/song/1188684829
#   https://music.apple.com/in/song/1188684830
#   https://music.apple.com/in/song/1188684831
#   https://music.apple.com/in/song/1188684832
#   https://music.apple.com/in/song/1188684833
# 50 Glorious Musical Years (The Complete Works) (2017):
#   https://music.apple.com/in/song/1189151367
#   https://music.apple.com/in/song/1189151368
#   https://music.apple.com/in/song/1189151370
#   https://music.apple.com/in/song/1189151371
#   https://music.apple.com/in/song/1189151372
#   https://music.apple.com/in/song/1189151373
#   https://music.apple.com/in/song/1189151379
#   https://music.apple.com/in/song/1189152572
#   https://music.apple.com/in/song/1189152573
#   https://music.apple.com/in/song/1189153221
#   https://music.apple.com/in/song/1189153224
#   https://music.apple.com/in/song/1189153226
#   https://music.apple.com/in/song/1189153229
#   https://music.apple.com/in/song/1189153230
#   https://music.apple.com/in/song/1189153234
#   https://music.apple.com/in/song/1189153236
#   https://music.apple.com/in/song/1189153239
#   https://music.apple.com/in/song/1189153483
#   https://music.apple.com/in/song/1189153486
#   https://music.apple.com/in/song/1189153503
#   https://music.apple.com/in/song/1189153510
#   https://music.apple.com/in/song/1189153517
#   https://music.apple.com/in/song/1189153518
#   https://music.apple.com/in/song/1189153519
#   https://music.apple.com/in/song/1189153521
#   https://music.apple.com/in/song/1189153522
#   https://music.apple.com/in/song/1189153523
#   https://music.apple.com/in/song/1189153524
#   https://music.apple.com/in/song/1189153525
# Timeless at 50 : A. R. Rahman, Vol. 2 (2017):
#   https://music.apple.com/in/song/1189171120
#   https://music.apple.com/in/song/1189171639
#   https://music.apple.com/in/song/1189171650
#   https://music.apple.com/in/song/1189171651
#   https://music.apple.com/in/song/1189171691
#   https://music.apple.com/in/song/1189171697
#   https://music.apple.com/in/song/1189171698
#   https://music.apple.com/in/song/1189171699
#   https://music.apple.com/in/song/1189171700
#   https://music.apple.com/in/song/1189171701
#   https://music.apple.com/in/song/1189171708
#   https://music.apple.com/in/song/1189171711
#   https://music.apple.com/in/song/1189171712
#   https://music.apple.com/in/song/1189171713
#   https://music.apple.com/in/song/1189171714
#   https://music.apple.com/in/song/1189171717
#   https://music.apple.com/in/song/1189171718
#   https://music.apple.com/in/song/1189171719
#   https://music.apple.com/in/song/1189171720
#   https://music.apple.com/in/song/1189171781
#   https://music.apple.com/in/song/1189171788
#   https://music.apple.com/in/song/1189171829
#   https://music.apple.com/in/song/1189171830
#   https://music.apple.com/in/song/1189171831
#   https://music.apple.com/in/song/1189171832
# Azhagiye (From "Kaatru Veliyidai") - Single (2017):
#   https://music.apple.com/in/song/1199883090
# Vaan (From "Kaatru Veliyidai") - Single (2017):
#   https://music.apple.com/in/song/1204246068
# Tu Hai (MTV Unplugged Season 6) - Single (2017):
#   https://music.apple.com/in/song/1208892083
# Saarattu Vandiyila (From "Kaatru Veliyidai") - Single (2017):
#   https://music.apple.com/in/song/1209490587
# Kaatru Veliyidai (Original Motion Picture Soundtrack) (2017):
#   https://music.apple.com/in/song/1215596355
#   https://music.apple.com/in/song/1215596662
#   https://music.apple.com/in/song/1215596663
#   https://music.apple.com/in/song/1215596664
#   https://music.apple.com/in/song/1215596668
#   https://music.apple.com/in/song/1215596674
# Cheliyaa (Original Motion Picture Soundtrack) (2017):
#   https://music.apple.com/in/song/1215599251
#   https://music.apple.com/in/song/1215599323
#   https://music.apple.com/in/song/1215599335
#   https://music.apple.com/in/song/1215599487
#   https://music.apple.com/in/song/1215599526
#   https://music.apple.com/in/song/1215599545
# Hind Mere Jind (From "Sachin - A Billion Dreams") - Single (2017):
#   https://music.apple.com/in/song/1229198683
# Sachin Sachin (From "Sachin - A Billion Dreams") [feat. Kaly] - Single (2017):
#   https://music.apple.com/in/song/1234218446
# Sachin - A Billion Dreams (Original Motion Picture Soundtrack) (2017):
#   https://music.apple.com/in/song/1237594376
#   https://music.apple.com/in/song/1237594378
#   https://music.apple.com/in/song/1237594661
# Mom (Original Motion Picture Soundtrack) (2017):
#   https://music.apple.com/in/song/1252985377
#   https://music.apple.com/in/song/1252985378
#   https://music.apple.com/in/song/1252985379
#   https://music.apple.com/in/song/1252985380
#   https://music.apple.com/in/song/1252985474
#   https://music.apple.com/in/song/1252985476
#   https://music.apple.com/in/song/1252985480
# Partition : 1947 (Original Motion Picture Soundtrack) - Single (2017):
#   https://music.apple.com/in/song/1255379213
#   https://music.apple.com/in/song/1255379216
#   https://music.apple.com/in/song/1255379217
# Agar Tum Saath Ho-Maahi Ve (From "T-Series Mixtape") - Single (2017):
# Mom (Tamil) [Original Motion Picture Soundtrack] (2017):
#   https://music.apple.com/in/song/1261460683
#   https://music.apple.com/in/song/1261460687
#   https://music.apple.com/in/song/1261460691
#   https://music.apple.com/in/song/1261460695
# A. R. Rahman Classics (2017):
#   https://music.apple.com/in/song/1263856115
#   https://music.apple.com/in/song/1263856116
#   https://music.apple.com/in/song/1263856117
#   https://music.apple.com/in/song/1263856118
#   https://music.apple.com/in/song/1263856119
#   https://music.apple.com/in/song/1263856120
#   https://music.apple.com/in/song/1263856305
#   https://music.apple.com/in/song/1263856310
#   https://music.apple.com/in/song/1263856311
#   https://music.apple.com/in/song/1263856312
#   https://music.apple.com/in/song/1263856313
#   https://music.apple.com/in/song/1263856314
#   https://music.apple.com/in/song/1263856318
#   https://music.apple.com/in/song/1263856319
#   https://music.apple.com/in/song/1263856320
#   https://music.apple.com/in/song/1263856321
#   https://music.apple.com/in/song/1263856322
#   https://music.apple.com/in/song/1263856323
#   https://music.apple.com/in/song/1263856324
#   https://music.apple.com/in/song/1263856325
#   https://music.apple.com/in/song/1263856326
#   https://music.apple.com/in/song/1263856327
#   https://music.apple.com/in/song/1263856328
#   https://music.apple.com/in/song/1263856329
#   https://music.apple.com/in/song/1263856330
#   https://music.apple.com/in/song/1263856422
#   https://music.apple.com/in/song/1263856423
#   https://music.apple.com/in/song/1263856424
#   https://music.apple.com/in/song/1263856425
# Aalaporaan Thamizhan (From "Mersal") - Single (2017):
#   https://music.apple.com/in/song/1269584948
# Neethanae (From "Mersal") - Single (2017):
#   https://music.apple.com/in/song/1272720772
# Mersal (Original Motion Picture Soundtrack) (2017):
#   https://music.apple.com/in/song/1273602654
#   https://music.apple.com/in/song/1273602655
#   https://music.apple.com/in/song/1273602659
#   https://music.apple.com/in/song/1273602660
# The Definitive Collection (2018):
#   https://music.apple.com/in/song/1328411334
#   https://music.apple.com/in/song/1328411335
#   https://music.apple.com/in/song/1328411336
#   https://music.apple.com/in/song/1328411337
#   https://music.apple.com/in/song/1328411338
#   https://music.apple.com/in/song/1328411339
#   https://music.apple.com/in/song/1328411340
#   https://music.apple.com/in/song/1328411341
#   https://music.apple.com/in/song/1328411342
#   https://music.apple.com/in/song/1328411343
#   https://music.apple.com/in/song/1328411344
#   https://music.apple.com/in/song/1328411345
#   https://music.apple.com/in/song/1328411346
#   https://music.apple.com/in/song/1328411384
#   https://music.apple.com/in/song/1328411385
#   https://music.apple.com/in/song/1328411386
#   https://music.apple.com/in/song/1328411387
#   https://music.apple.com/in/song/1328411388
#   https://music.apple.com/in/song/1328411389
#   https://music.apple.com/in/song/1328411390
#   https://music.apple.com/in/song/1328411391
#   https://music.apple.com/in/song/1328411392
#   https://music.apple.com/in/song/1328411393
#   https://music.apple.com/in/song/1328411394
#   https://music.apple.com/in/song/1328411395
#   https://music.apple.com/in/song/1328411396
#   https://music.apple.com/in/song/1328411398
#   https://music.apple.com/in/song/1328411399
#   https://music.apple.com/in/song/1328411400
#   https://music.apple.com/in/song/1328411401
#   https://music.apple.com/in/song/1328411403
#   https://music.apple.com/in/song/1328411404
#   https://music.apple.com/in/song/1328411405
#   https://music.apple.com/in/song/1328411406
#   https://music.apple.com/in/song/1328411407
#   https://music.apple.com/in/song/1328411408
#   https://music.apple.com/in/song/1328411409
#   https://music.apple.com/in/song/1328411410
#   https://music.apple.com/in/song/1328411411
#   https://music.apple.com/in/song/1328411412
#   https://music.apple.com/in/song/1328411413
#   https://music.apple.com/in/song/1328411414
#   https://music.apple.com/in/song/1328411416
#   https://music.apple.com/in/song/1328411417
#   https://music.apple.com/in/song/1328411419
#   https://music.apple.com/in/song/1328411421
#   https://music.apple.com/in/song/1328411422
# The Best of A. R. Rahman (2018):
#   https://music.apple.com/in/song/1332299133
#   https://music.apple.com/in/song/1332299134
#   https://music.apple.com/in/song/1332299135
#   https://music.apple.com/in/song/1332299136
#   https://music.apple.com/in/song/1332299137
#   https://music.apple.com/in/song/1332299138
#   https://music.apple.com/in/song/1332299139
#   https://music.apple.com/in/song/1332299140
#   https://music.apple.com/in/song/1332299531
#   https://music.apple.com/in/song/1332299532
#   https://music.apple.com/in/song/1332299533
#   https://music.apple.com/in/song/1332299534
# Beyond the Clouds (Original Motion Picture Soundtrack) (2018):
#   https://music.apple.com/in/song/1367133627
#   https://music.apple.com/in/song/1367133628
#   https://music.apple.com/in/song/1367133625
#   https://music.apple.com/in/song/1367133615
#   https://music.apple.com/in/song/1367133616
#   https://music.apple.com/in/song/1367133617
#   https://music.apple.com/in/song/1367133618
#   https://music.apple.com/in/song/1367133619
#   https://music.apple.com/in/song/1367133629
#   https://music.apple.com/in/song/1367133620
#   https://music.apple.com/in/song/1367133621
#   https://music.apple.com/in/song/1367133622
#   https://music.apple.com/in/song/1367133623
#   https://music.apple.com/in/song/1367133624
#   https://music.apple.com/in/song/1367133626
# Ruby Ruby (From "Sanju") - Single (2018):
#   https://music.apple.com/in/song/1399556123
# Sanju (Original Motion Picture Soundtrack) (2018):
#   https://music.apple.com/in/song/1405546220
#   https://music.apple.com/in/song/1405546221
#   https://music.apple.com/in/song/1405546222
#   https://music.apple.com/in/song/1405546223
#   https://music.apple.com/in/song/1405546226
#   https://music.apple.com/in/song/1405546227
# Bhoomi Bhoomi (From "Chekka Chivantha Vaanam") - Single (2018):
#   https://music.apple.com/in/song/1435303306
# Mazhai Kuruvi (From "Chekka Chivantha Vaanam") - Single (2018):
#   https://music.apple.com/in/song/1435303899
# Sevandhu Pochu Nenju (From "Chekka Chivantha Vaanam") - Single (2018):
#   https://music.apple.com/in/song/1436315697
# Kalla Kalavaani (From "Chekka Chivantha Vaanam") - Single (2018):
#   https://music.apple.com/in/song/1436587046
# Hayati (From "Chekka Chivantha Vaanam") - Single (2018):
#   https://music.apple.com/in/song/1437398913
# Chekka Chivantha Vaanam (Original Motion Picture Soundtrack) (2018):
#   https://music.apple.com/in/song/1437604279
#   https://music.apple.com/in/song/1437604280
#   https://music.apple.com/in/song/1437604281
#   https://music.apple.com/in/song/1437604282
#   https://music.apple.com/in/song/1437604283
#   https://music.apple.com/in/song/1437604284
#   https://music.apple.com/in/song/1437604285
# Nawab (Original Motion Picture Soundtrack) (2018):
#   https://music.apple.com/in/song/1437605224
#   https://music.apple.com/in/song/1437605226
#   https://music.apple.com/in/song/1437605228
#   https://music.apple.com/in/song/1437605229
#   https://music.apple.com/in/song/1437605382
#   https://music.apple.com/in/song/1437605383
#   https://music.apple.com/in/song/1437605384
# Sarkar (Tamil) [Original Motion Picture Soundtrack] (2018):
#   https://music.apple.com/in/song/1437977154
#   https://music.apple.com/in/song/1437977155
#   https://music.apple.com/in/song/1437977159
#   https://music.apple.com/in/song/1437977161
#   https://music.apple.com/in/song/1437977162
# Singappenney (From "Bigil") - Single (2019):
#   https://music.apple.com/in/song/1474045348
# Verithanam (From "Bigil") - Single (2019):
#   https://music.apple.com/in/song/1478552737
# Bigil (Original Motion Picture Soundtrack) (2019):
#   https://music.apple.com/in/song/1480710137
#   https://music.apple.com/in/song/1480710139
#   https://music.apple.com/in/song/1480710140
#   https://music.apple.com/in/song/1480710143
#   https://music.apple.com/in/song/1480710269
# Street Dancer 3D (Original Motion Picture Soundtrack) (2020):
#   https://music.apple.com/in/song/1498888985
#   https://music.apple.com/in/song/1498889226
#   https://music.apple.com/in/song/1498889227
#   https://music.apple.com/in/song/1498889228
#   https://music.apple.com/in/song/1498889229
#   https://music.apple.com/in/song/1498889230
#   https://music.apple.com/in/song/1498889231
#   https://music.apple.com/in/song/1498889232
#   https://music.apple.com/in/song/1498889233
#   https://music.apple.com/in/song/1498889234
#   https://music.apple.com/in/song/1498889235
# 99 Songs (Original Motion Picture Soundtrack) (2020):
#   https://music.apple.com/in/song/1503457395
#   https://music.apple.com/in/song/1503457397
#   https://music.apple.com/in/song/1503457398
#   https://music.apple.com/in/song/1503457401
#   https://music.apple.com/in/song/1503457402
#   https://music.apple.com/in/song/1503457403
#   https://music.apple.com/in/song/1503457410
#   https://music.apple.com/in/song/1503457786
#   https://music.apple.com/in/song/1503457791
#   https://music.apple.com/in/song/1503457794
#   https://music.apple.com/in/song/1503457797
#   https://music.apple.com/in/song/1503457798
#   https://music.apple.com/in/song/1503457803
#   https://music.apple.com/in/song/1503457804
# Thumbi Thullal (From "Cobra") - Single (2020):
#   https://music.apple.com/in/song/1521232204
# Dil Bechara (Original Motion Picture Soundtrack) (2020):
#   https://music.apple.com/in/song/1522841930
#   https://music.apple.com/in/song/1522841933
#   https://music.apple.com/in/song/1522842100
#   https://music.apple.com/in/song/1522842103
#   https://music.apple.com/in/song/1522842104
#   https://music.apple.com/in/song/1522842105
#   https://music.apple.com/in/song/1522842109
#   https://music.apple.com/in/song/1522842112
#   https://music.apple.com/in/song/1522842116
# Garmi Non Stop Dance Mix (2020):
#   https://music.apple.com/in/song/1546582886
# 99 Songs (Tamil) [Original Motion Picture Soundtrack] (2021):
#   https://music.apple.com/in/song/1560166714
#   https://music.apple.com/in/song/1560166986
#   https://music.apple.com/in/song/1560166990
#   https://music.apple.com/in/song/1560166991
#   https://music.apple.com/in/song/1560166992
#   https://music.apple.com/in/song/1560166995
#   https://music.apple.com/in/song/1560166998
#   https://music.apple.com/in/song/1560167000
#   https://music.apple.com/in/song/1560167001
#   https://music.apple.com/in/song/1560167004
#   https://music.apple.com/in/song/1560167006
#   https://music.apple.com/in/song/1560167007
#   https://music.apple.com/in/song/1560167009
#   https://music.apple.com/in/song/1560167010
# Mimi (Original Motion Picture Soundtrack) (2021):
#   https://music.apple.com/in/song/1576395278
#   https://music.apple.com/in/song/1576395281
#   https://music.apple.com/in/song/1576395282
#   https://music.apple.com/in/song/1576395288
#   https://music.apple.com/in/song/1576395291
#   https://music.apple.com/in/song/1576395292
#   https://music.apple.com/in/song/1576395293
# Atrangi Re (Original Motion Picture Soundtrack) (2021):
#   https://music.apple.com/in/song/1598907457
#   https://music.apple.com/in/song/1598907458
#   https://music.apple.com/in/song/1598907459
#   https://music.apple.com/in/song/1598907460
#   https://music.apple.com/in/song/1598907461
#   https://music.apple.com/in/song/1598907462
#   https://music.apple.com/in/song/1598907463
# Sivaji (Original Motion Picture Soundtrack) (2022):
#   https://music.apple.com/in/song/1619047420
#   https://music.apple.com/in/song/1619047421
#   https://music.apple.com/in/song/1619047422
#   https://music.apple.com/in/song/1619047423
#   https://music.apple.com/in/song/1619047424
#   https://music.apple.com/in/song/1619047425
#   https://music.apple.com/in/song/1619047426
# Heropanti 2 (Original Motion Picture Soundtrack) (2022):
#   https://music.apple.com/in/song/1622149023
#   https://music.apple.com/in/song/1622149024
#   https://music.apple.com/in/song/1622149025
#   https://music.apple.com/in/song/1622149176
#   https://music.apple.com/in/song/1622149177
# Cobra (Original Motion Picture Soundtrack) (2022):
#   https://music.apple.com/in/song/1634155546
#   https://music.apple.com/in/song/1634155552
#   https://music.apple.com/in/song/1634155555
#   https://music.apple.com/in/song/1634155556
#   https://music.apple.com/in/song/1634155557
# Ponni Nadhi (From "Ponniyin Selvan Part -1") - Single (2022):
#   https://music.apple.com/in/song/1637244352
# Vendhu Thanindhathu Kaadu (Original Motion Picture Soundtrack) (2022):
#   https://music.apple.com/in/song/1643146593
#   https://music.apple.com/in/song/1643146604
#   https://music.apple.com/in/song/1643146939
#   https://music.apple.com/in/song/1643146940
#   https://music.apple.com/in/song/1643146945
# The Life Of Muthu (Original Motion Picture Soundtrack) (2022):
#   https://music.apple.com/in/song/1645358178
#   https://music.apple.com/in/song/1645358191
#   https://music.apple.com/in/song/1645358198
#   https://music.apple.com/in/song/1645358476
# Mili (Original Motion Picture Soundtrack) (2022):
#   https://music.apple.com/in/song/1653398676
#   https://music.apple.com/in/song/1653398677
#   https://music.apple.com/in/song/1653398678
#   https://music.apple.com/in/song/1653398679
#   https://music.apple.com/in/song/1653398680
# Pathu Thala (Original Motion Picture Soundtrack) (2023):
#   https://music.apple.com/in/song/1677929707
#   https://music.apple.com/in/song/1677929708
#   https://music.apple.com/in/song/1677929709
#   https://music.apple.com/in/song/1677929710
# Osarattum Pathu Thala (From "Pathu Thala") - Single (2023):
#   https://music.apple.com/in/song/1679404309
# Maamannan (Original Motion Picture Soundtrack) (2023):
#   https://music.apple.com/in/song/1690586449
#   https://music.apple.com/in/song/1690586454
#   https://music.apple.com/in/song/1690586455
#   https://music.apple.com/in/song/1690586456
#   https://music.apple.com/in/song/1690586459
#   https://music.apple.com/in/song/1690586462
#   https://music.apple.com/in/song/1690586463
# Ranvijay's Entry Medley (From "ANIMAL") - Single (2023):
#   https://music.apple.com/in/song/1721328387
# ANIMAL (Deluxe Edition Album) (2024):
#   https://music.apple.com/in/song/1727144164
#   https://music.apple.com/in/song/1727144176
#   https://music.apple.com/in/song/1727144339
#   https://music.apple.com/in/song/1727144349
#   https://music.apple.com/in/song/1727144597
#   https://music.apple.com/in/song/1727144606
#   https://music.apple.com/in/song/1727144808
#   https://music.apple.com/in/song/1727144815
#   https://music.apple.com/in/song/1727144821
#   https://music.apple.com/in/song/1727144822
#   https://music.apple.com/in/song/1727144824
#   https://music.apple.com/in/song/1727144825
#   https://music.apple.com/in/song/1727144826
#   https://music.apple.com/in/song/1727144827
#   https://music.apple.com/in/song/1727144828
#   https://music.apple.com/in/song/1727144829
#   https://music.apple.com/in/song/1727144830
# The Goat Life - Aadujeevitham (Original Motion Picture Soundtrack) - Single (2024):
#   https://music.apple.com/in/song/1735912871
#   https://music.apple.com/in/song/1735913302
#   https://music.apple.com/in/song/1735913313
# Amar Singh Chamkila (Original Motion Picture Soundtrack) - EP (2024):
#   https://music.apple.com/in/song/1738489822
#   https://music.apple.com/in/song/1738489826
#   https://music.apple.com/in/song/1738489838
#   https://music.apple.com/in/song/1738489840
#   https://music.apple.com/in/song/1738490189
#   https://music.apple.com/in/song/1738490199
# Raayan (Original Motion Picture Soundtrack) - EP (2024):
#   https://music.apple.com/in/song/1755895075
#   https://music.apple.com/in/song/1755895086
#   https://music.apple.com/in/song/1755895092
#   https://music.apple.com/in/song/1755895093
#   https://music.apple.com/in/song/1755895094
# Kadhalikka Neramillai (Original Motion Picture Soundtrack) - EP (2025):
#   https://music.apple.com/in/song/1789107469
#   https://music.apple.com/in/song/1789107471
#   https://music.apple.com/in/song/1789107472
#   https://music.apple.com/in/song/1789107476
#   https://music.apple.com/in/song/1789107477
# Chikiri Chikiri (From "Peddi") [TELUGU] - Single (2025):
#   https://music.apple.com/in/song/1851388336
# Aawaara Angaara (From "Tere Ishk Mein") - Single (2025):
#   https://music.apple.com/in/song/1852499035
# Tere Ishk Mein (Original Motion Picture Soundtrack) (2025):
#   https://music.apple.com/in/song/1852500177
#   https://music.apple.com/in/song/1852500178
#   https://music.apple.com/in/song/1852500179
#   https://music.apple.com/in/song/1852500180
#   https://music.apple.com/in/song/1852500181
#   https://music.apple.com/in/song/1852500182
#   https://music.apple.com/in/song/1852500183
#   https://music.apple.com/in/song/1852500184
#   https://music.apple.com/in/song/1852500185
# Peddi (Original Motion Picture Soundtrack) - TELUGU (2026):
#   https://music.apple.com/in/song/6774104080
#   https://music.apple.com/in/song/6774104083
#   https://music.apple.com/in/song/6774104084
#   https://music.apple.com/in/song/6774104086
# Main Vaapas Aaunga (Original Motion Picture Soundtrack) (2026):
#   https://music.apple.com/in/song/6778782201
#   https://music.apple.com/in/song/6778782202
#   https://music.apple.com/in/song/6778782204
#   https://music.apple.com/in/song/6778782205
#   https://music.apple.com/in/song/6778782208
#   https://music.apple.com/in/song/6778782209
#   https://music.apple.com/in/song/6778782212
#   https://music.apple.com/in/song/6778782213
# Out:
# Writing songlist.txt

# %%
# copyright 2023 © Xron Trix | https://github.com/Xrontrix10


# @title 🖥️ Main Colab Leech Code

# @title Main Code
# @markdown <div><center><img src="https://user-images.githubusercontent.com/125879861/255391401-371f3a64-732d-4954-ac0f-4f093a6605e1.png" height=80></center></div>
# @markdown <center><h4><a href="https://github.com/XronTrix10/Telegram-Leecher/wiki/INSTRUCTIONS">READ</a> How to use</h4></center>

# @markdown <br>
# @markdown ### 🤖 Telegram Bot Configuration *(required)*
API_ID = 123456  # TODO: replace with YOUR real value
API_HASH = 'YOUR_API_HASH'  # TODO: replace with YOUR real value
BOT_TOKEN = "YOUR_BOT_TOKEN"  # TODO: replace with YOUR real value
USER_ID = 1720179071  # @param {type: "integer"}
DUMP_ID = -1004303738393  # @param {type: "integer"}

# @markdown ---
# @markdown ### ☁️ S3 / Wasabi / B2 Configuration *(optional — needed only for `/s3upload` and `/s3leech`)*
# @markdown
# @markdown Works with **AWS, Wasabi, Backblaze B2, Cloudflare R2, DigitalOcean Spaces, MinIO** and any other S3-compatible service.
# @markdown Leave the five fields below blank if you don't plan to use S3.
# @markdown
# @markdown <details><summary><b>📋 Click to expand: copy-paste examples for every provider</b></summary>
# @markdown
# @markdown #### 🟧 AWS S3
# @markdown ```text
# @markdown S3_ACCESS_KEY    = AKIA****************
# @markdown S3_SECRET_KEY    = ****************************************
# @markdown S3_BUCKET_NAME   = my-leecher-bucket
# @markdown S3_ENDPOINT_URL  =                          ← LEAVE EMPTY for AWS
# @markdown S3_REGION        = us-east-1                ← bucket's region
# @markdown ```
# @markdown
# @markdown #### 🟩 Wasabi (most popular for Colab — no egress fees)
# @markdown ```text
# @markdown S3_ACCESS_KEY    = FYTC********  ← from Wasabi → Access Keys → Create New
# @markdown S3_SECRET_KEY    = bKye************************************
# @markdown S3_BUCKET_NAME   = my-wasabi-bucket
# @markdown S3_ENDPOINT_URL  = https://s3.ap-northeast-1.wasabisys.com    ← match region!
# @markdown S3_REGION        = ap-northeast-1
# @markdown ```
# @markdown <sub>Region table: us-east-1 / us-east-2 / us-central-1 / us-west-1 / ca-central-1 / eu-central-1 / eu-central-2 / eu-west-1 / eu-west-2 / ap-northeast-1 / ap-northeast-2 / ap-southeast-1 / ap-southeast-2. Endpoint is always <code>https://s3.&lt;region&gt;.wasabisys.com</code></sub>
# @markdown
# @markdown #### 🟥 Backblaze B2
# @markdown ```text
# @markdown S3_ACCESS_KEY    = 0026****************    ← keyID from B2 → Application Keys
# @markdown S3_SECRET_KEY    = K002****************    ← applicationKey (shown ONCE)
# @markdown S3_BUCKET_NAME   = my-b2-bucket
# @markdown S3_ENDPOINT_URL  = https://s3.us-west-002.backblazeb2.com    ← from bucket page
# @markdown S3_REGION        = us-west-002             ← region segment of endpoint
# @markdown ```
# @markdown
# @markdown #### 🟧 Cloudflare R2 (zero egress fees)
# @markdown ```text
# @markdown S3_ACCESS_KEY    = ********************    ← R2 → Manage R2 API Tokens
# @markdown S3_SECRET_KEY    = ****************************************
# @markdown S3_BUCKET_NAME   = my-r2-bucket
# @markdown S3_ENDPOINT_URL  = https://<account-id>.r2.cloudflarestorage.com
# @markdown S3_REGION        = auto                    ← literal string "auto" — R2 quirk
# @markdown ```
# @markdown
# @markdown #### 🟦 DigitalOcean Spaces
# @markdown ```text
# @markdown S3_ACCESS_KEY    = DO00****************
# @markdown S3_SECRET_KEY    = ****************************************
# @markdown S3_BUCKET_NAME   = my-do-space
# @markdown S3_ENDPOINT_URL  = https://nyc3.digitaloceanspaces.com   ← e.g. nyc3 / sfo3 / ams3 / sgp1 / fra1
# @markdown S3_REGION        = nyc3                                  ← match the region in URL
# @markdown ```
# @markdown
# @markdown #### ⬛ MinIO / self-hosted
# @markdown ```text
# @markdown S3_ACCESS_KEY    = <your-access-key>
# @markdown S3_SECRET_KEY    = <your-secret-key>
# @markdown S3_BUCKET_NAME   = my-minio-bucket
# @markdown S3_ENDPOINT_URL  = https://your-minio.example.com   ← public HTTPS endpoint
# @markdown S3_REGION        = us-east-1                        ← MinIO default
# @markdown ```
# @markdown
# @markdown #### 🟪 Storj DCS / Linode / Scaleway / IDrive e2 / Vultr / OVH / Yandex / Alibaba
# @markdown ```text
# @markdown S3_ENDPOINT_URL  = https://<provider-endpoint-from-their-docs>
# @markdown S3_REGION        = <region-as-required-by-provider>
# @markdown ```
# @markdown <sub>Full list with endpoints in <a href="https://github.com/ajithvnr2001/Telegram-Leecher/blob/main/docs/S3_GUIDE.md#other-s3-compatible-providers">docs/S3_GUIDE.md → Other S3-compatible providers</a></sub>
# @markdown
# @markdown </details>
# @markdown
# @markdown ---
S3_ACCESS_KEY = 'YOUR_S3_ACCESS_KEY'  # TODO: replace with YOUR real value
S3_SECRET_KEY = 'YOUR_S3_SECRET_KEY'  # TODO: replace with YOUR real value
S3_BUCKET_NAME = "musicapple"  # @param {type: "string"}   ← e.g. musicapple (also hosts am-tools + music-logs)
S3_ENDPOINT_URL = "https://s3.ap-northeast-1.wasabisys.com"  # @param {type: "string"}  ← e.g. https://s3.ap-northeast-1.wasabisys.com
S3_REGION = "ap-northeast-1"  # @param {type: "string"}

# @markdown ---
# @markdown ### 🎵 Apple Music Download Configuration *(optional — needed only for `/amusic`)*
# @markdown
# @markdown `/amusic` downloads the predefined Apple Music link below through **ALL formats** (ALAC, Dolby Atmos/EC3, AAC-LC 256, AAC 128, HE-AAC 64), into `/music`, mirrors each format's batch log to S3 (`music-logs/<format>-batchNN.log`) and uploads every new track to Telegram.
# @markdown `/amusic local` saves everything to `/content` (Colab disk) instead — **no Telegram upload**, files just stay local.
# @markdown
# @markdown **Two link types are supported:**
# @markdown - **Playlist** (`.../playlist/...`) — downloaded in batches of 5 songs, then all its Music Videos at max quality.
# @markdown - **Artist** (`.../artist/<name>/<id>`, e.g. `https://music.apple.com/in/artist/a-r-rahman/3249567`) — ALL of the artist's albums are resolved via the Apple Music API (oldest release first) and downloaded **one album per batch**, then the artist-wide Music Videos at max quality.
# @markdown
# @markdown **Unified naming convention** — every format uses the same pattern `{SongNumber}.{SongName}.{FORMAT}.{VARIANT}.m4a`, so each song yields 5 files:
# @markdown ```
# @markdown 01.KangalIrandal.ALAC.Lossless.m4a
# @markdown 01.KangalIrandal.ATMOS.Dolby.m4a
# @markdown 01.KangalIrandal.AAC.256Kbps.m4a
# @markdown 01.KangalIrandal.AAC.128Kbps.m4a
# @markdown 01.KangalIrandal.AAC.64Kbps.m4a
# @markdown ```
# @markdown
# @markdown **Fields:**
# @markdown - `AM_PLAYLIST_URL` — **playlist** link (downloaded in 5-song batches, then its MVs).
# @markdown - `AM_ARTIST_URL` — **artist** link (ALL albums oldest-first, one album per batch, then the artist-wide MVs).
# @markdown - You can set **both** at once — each source runs as its own pass and keeps a **separate S3 log keyspace**, so resuming a playlist never reads artist logs and vice versa.
# @markdown - `AM_MEDIA_TOKEN` — your Apple Music `media-user-token` (required for AAC-LC / Atmos / ALAC from an active subscription). ⚠️ **Paste your own token — never commit it.**
# @markdown - `AM_AUTH_TOKEN` — optional pinned Authorization JWT. Set it when am-downloader's own token scrape comes back empty from your IP/locale (every MV then fails with "media-user-token may wrong or expired"). Get a fresh one by opening `music.apple.com` → DevTools → Network → any request → Authorization header (`Bearer eyJ...`). Valid ~2 months.
# @markdown - `AM_ALBUM_LIMIT` — artist mode only: max number of albums to download (0 = ALL; `2` = only the 2 oldest).
# @markdown - `AM_MV_LIMIT` — artist mode only: max number of artist music videos to download (0 = all).
# @markdown
# @markdown The am-downloader toolchain (wrapper + binary) is fetched automatically on the first `/amusic` run.
AM_PLAYLIST_URL = ""  # @param {type: "string"}
AM_ARTIST_URL = "https://music.apple.com/in/artist/a-r-rahman/3249567"  # @param {type: "string"}
AM_MEDIA_TOKEN = "YOUR_AM_MEDIA_TOKEN"  # TODO: replace with YOUR real value
AM_AUTH_TOKEN = ""  # @param {type: "string"}
AM_ALBUM_LIMIT = 2  # @param {type: "integer"}
AM_MV_LIMIT = 2  # @param {type: "integer"}

# @markdown ---
# @markdown ### 🧾 Songlist mode *(optional)*
# @markdown `/amusic songs` bulk-downloads the song list in `/content/songlist.txt` through **ALL formats**. Resume state is one **single appended log** in S3 (`music-logs/songlist-dedupe.log`) — every completed track×format is a line, so a Colab restart continues exactly where it stopped without re-downloading.
# @markdown - `AM_SONGLIST_AUTO` = tick → the bot starts the songlist **automatically right after startup** — no `/amusic` START click.
# @markdown - `SONGLIST_URL` — optional http(s) or `s3://bucket/key` URL the cell fetches the songlist from (or upload `/content/songlist.txt` yourself).
# @markdown - **How to generate the songlist** (artist / album / playlist → `songlist.txt`): see [guide/SONGLIST_EXTRACTION.md](https://github.com/ajithvnr2001/Telegram-Leecher/blob/main/guide/SONGLIST_EXTRACTION.md) — includes its crash/resume semantics and troubleshooting.
# @markdown - Order guarantee: **download → upload to Telegram → log append**, so a crash mid-chunk re-runs only that chunk and nothing is lost.
AM_SONGLIST_AUTO = True  # @param {type: "boolean"}
SONGLIST_URL = "\"s3://musicapple/songlist.txt\""  # @param {type: "string"}

# @markdown ---
# @markdown ### 📚 Quick command cheat sheet
# @markdown - `/tupload` &nbsp;&nbsp;— leech links to Telegram
# @markdown - `/gdupload` — mirror to Google Drive
# @markdown - `/ytupload` — YouTube / yt-dlp leech
# @markdown - `/drupload` — leech a local Colab folder
# @markdown - `/amusic` &nbsp;&nbsp;**🎵 NEW** &nbsp;— download the predefined Apple Music playlist **or artist albums + MVs** in ALL formats (ALAC / Atmos / AAC) with a unified naming convention and upload to Telegram; `/amusic local` keeps files on the Colab disk (no upload)
# @markdown - `/amusic songs` &nbsp;&nbsp;**🧾 NEW** &nbsp;— bulk-download `/content/songlist.txt` in ALL formats (single appended S3 dedupe log, restart-proof; tick `AM_SONGLIST_AUTO` for full auto after startup)
# @markdown - `/s3upload` &nbsp;**☁️ NEW** &nbsp;— mirror downloads to your S3 / Wasabi bucket (>2 GB OK, multipart)
# @markdown - `/s3leech` &nbsp;&nbsp;**📥 NEW** &nbsp;— leech `s3://bucket/key` or `s3://bucket/folder/` to Telegram
# @markdown - `/s3bucket <name>` — change destination bucket on the fly
# @markdown - `/s3prefix <folder>` — set a destination key prefix
# @markdown
# @markdown #### 🔁 **Whole-bucket iterative mode + crash-resume** (auto)
# @markdown - Point `/s3leech` or `/s3upload` at `s3://my-bucket/` or `s3://my-bucket/folder/` and the bot processes objects **one at a time** (download → split if >2 GB → upload → cleanup → next). Works for terabyte-sized buckets on a 84 GB Colab disk.
# @markdown - The tracker is mirrored to `s3://<S3_BUCKET_NAME>/s3teletracker.json` after every transfer, so if Colab crashes mid-batch you can simply re-run the same command in a fresh runtime — the bot skips already-processed objects and resumes from where it left off.
# @markdown - To force a full re-run, delete `s3teletracker.json` from the bucket via your provider's web console.
# @markdown
# @markdown <details><summary><b>📨 Click for ready-to-paste sample DM commands</b></summary>
# @markdown
# @markdown **Mirror an internet file → S3 (Regular)**
# @markdown ```text
# @markdown /s3upload
# @markdown
# @markdown https://speed.hetzner.de/100MB.bin
# @markdown [test-100mb.bin]
# @markdown ```
# @markdown
# @markdown **Mirror a Google Drive link → S3 (Compress)**
# @markdown ```text
# @markdown /s3upload
# @markdown
# @markdown https://drive.google.com/file/d/<file-id>/view
# @markdown [my-archive.zip]
# @markdown {zip-pw-if-any}
# @markdown ```
# @markdown
# @markdown **Leech a single S3 object → Telegram**
# @markdown ```text
# @markdown /s3leech
# @markdown
# @markdown s3://my-bucket/Uploaded__2026-05-28_19-45-21/test-100mb.bin
# @markdown ```
# @markdown
# @markdown **Leech a whole S3 folder/prefix → Telegram (zipped)**
# @markdown ```text
# @markdown /s3leech
# @markdown
# @markdown s3://my-bucket/photos/vacation-2025/
# @markdown {gallery-pw}
# @markdown ```
# @markdown
# @markdown **Copy from one S3 bucket to another**
# @markdown ```text
# @markdown /s3bucket destination-bucket
# @markdown /s3upload
# @markdown
# @markdown s3://source-bucket/path/to/file.mkv
# @markdown ```
# @markdown
# @markdown **Set a persistent S3 destination prefix, then mirror many files**
# @markdown ```text
# @markdown /s3prefix archive/2026-Q2
# @markdown /s3upload
# @markdown
# @markdown https://example.com/a.iso
# @markdown https://example.com/b.iso
# @markdown https://example.com/c.iso
# @markdown ```
# @markdown
# @markdown **Extract an archive that lives in S3 → mirror contents to Drive**
# @markdown ```text
# @markdown /gdupload
# @markdown
# @markdown s3://my-bucket/backups/2026-05-01.tar.gz
# @markdown (archive_password)
# @markdown ```
# @markdown
# @markdown **Big-file (>2 GB) S3 → Telegram (auto-split into <2 GB parts)**
# @markdown ```text
# @markdown /s3leech
# @markdown
# @markdown s3://my-bucket/movies/big-blockbuster-5gb.mkv
# @markdown [Movie Title.mkv]
# @markdown ```
# @markdown
# @markdown **Whole bucket → Telegram (iterative + auto-resume on Colab crash)**
# @markdown ```text
# @markdown /s3leech
# @markdown
# @markdown s3://my-bucket/                          ← whole bucket
# @markdown ```
# @markdown <sub>Bot processes objects one-at-a-time, splits >2 GB to &lt;2 GB Telegram parts, persists tracker to <code>s3://&lt;S3_BUCKET_NAME&gt;/s3teletracker.json</code> after each object. If Colab crashes, just re-run the same command — already-completed objects are skipped automatically.</sub>
# @markdown
# @markdown **Mirror whole bucket → another bucket (S3-to-S3, iterative + resume)**
# @markdown ```text
# @markdown /s3bucket destination-bucket
# @markdown /s3upload
# @markdown
# @markdown s3://source-bucket/folder/
# @markdown ```
# @markdown
# @markdown </details>
# @markdown
# @markdown All S3 transfers are logged to `/content/Telegram-Leecher/s3teletracker.json` with `uploaded` and `downloaded` arrays.
# @markdown
# @markdown 📖 In-depth provider walkthroughs (creds, IAM policy, region tables, gotchas): see <a href="https://github.com/ajithvnr2001/Telegram-Leecher/blob/main/docs/S3_GUIDE.md">docs/S3_GUIDE.md</a>


import subprocess, time, json, shutil, os
from IPython.display import clear_output
from threading import Thread

Working = True

banner = '''

 ____   ____.______  ._______  .______       _____._.______  .___  ____   ____
 \\   \\_/   /: __   \\ : .___  \\ :      \\      \\__ _:|: __   \\ : __| \\   \\_/   /
  \\___ ___/ |  \\____|| :   |  ||       |       |  :||  \\____|| : |  \\___ ___/
  /   _   \\ |   :  \\ |     :  ||   |   |       |   ||   :  \\ |   |  /   _   \\
 /___/ \\___\\|   |___\\ \\_. ___/ |___|   |       |   ||   |___\\|   | /___/ \\___\\
            |___|       :/         |___|       |___||___|    |___|
                        :


              _____     __     __     __              __
             / ___/__  / /__ _/ /    / / ___ ___ ____/ /  ___ ____
            / /__/ _ \\/ / _ `/ _ \\  / /_/ -_) -_) __/ _ \\/ -_) __/
            \\___/\\___/_/\\_,_/_.__/ /____|__/\\__/\\__/_//_/\\__/_/



'''

print(banner)

def Loading():
    white = 37
    black = 0
    while Working:
        print("\r" + "░"*white + "▒▒"+ "▓"*black + "▒▒" + "░"*white, end="")
        black = (black + 2) % 75
        white = (white -1) if white != 0 else 37
        time.sleep(2)
    clear_output()


_Thread = Thread(target=Loading, name="Prepare", args=())
_Thread.start()

if len(str(DUMP_ID)) == 10 and "-100" not in str(DUMP_ID):
    n_dump = "-100" + str(DUMP_ID)
    DUMP_ID = int(n_dump)

if os.path.exists("/content/sample_data"):
    shutil.rmtree("/content/sample_data")

# IMPORTANT: this MUST point to the fork + branch that contains the S3
# integration and the Python 3.12 event-loop fix. The original upstream repo
# does NOT have those changes, so cloning it brings back the old code and the
# "RuntimeError: There is no current event loop" crash.
# Default to main (all fixes are merged there). Switch REPO_BRANCH to a
# feature branch only when testing un-merged changes.
REPO_URL = "https://github.com/ajithvnr2001/Telegram-Leecher"  # @param {type:"string"}
REPO_BRANCH = "main"  # @param {type:"string"}

# Always start from a clean checkout so a stale/old clone can't linger.
subprocess.run("rm -rf /content/Telegram-Leecher", shell=True)
cmd = f"git clone -b {REPO_BRANCH} {REPO_URL} /content/Telegram-Leecher"
proc = subprocess.run(cmd, shell=True)
# Fallback: if the chosen branch doesn't exist (e.g. it was deleted after a
# merge), fall back to the default branch so the clone still succeeds.
if not os.path.exists("/content/Telegram-Leecher/colab_leecher/__init__.py"):
    print(f"Branch '{REPO_BRANCH}' not found — cloning default branch instead.")
    subprocess.run("rm -rf /content/Telegram-Leecher", shell=True)
    subprocess.run(f"git clone {REPO_URL} /content/Telegram-Leecher", shell=True)

# ---------------------------------------------------------------------------
# Event-loop safety patch (Python 3.12 + uvloop)
# uvloop.install() swaps the event-loop policy but does NOT create a loop, and
# Python 3.12 asyncio.get_event_loop() raises 'no current event loop' when none
# is set — which Pyrogram's Client()/Dispatcher() hits on import. This patch
# guarantees a loop is created+set right before the Client is built, and is
# idempotent: it's a no-op if the cloned code already has the fix, and it
# repairs the file even if an older/upstream revision was somehow cloned.
# ---------------------------------------------------------------------------
init_path = "/content/Telegram-Leecher/colab_leecher/__init__.py"
try:
    with open(init_path, "r") as _f:
        _src = _f.read()
    if "asyncio.new_event_loop()" not in _src and "colab_bot = Client(" in _src:
        if "import asyncio" not in _src:
            _src = "import asyncio\n" + _src
        _src = _src.replace(
            "colab_bot = Client(",
            "loop = asyncio.new_event_loop()\nasyncio.set_event_loop(loop)\ncolab_bot = Client(",
            1,
        )
        with open(init_path, "w") as _f:
            _f.write(_src)
        print("✅ Applied Python 3.12 event-loop safety patch to colab_leecher/__init__.py")
    else:
        print("✅ Event-loop fix already present in colab_leecher/__init__.py")
except Exception as _e:
    print(f"⚠️  Could not apply event-loop safety patch: {_e}")

cmd = "apt update && apt install -y ffmpeg aria2 gpac"
proc = subprocess.run(cmd, shell=True)
cmd = "pip3 install -r /content/Telegram-Leecher/requirements.txt"
proc = subprocess.run(cmd, shell=True)

# Validate S3 config (warn-only — bot still starts; /s3* commands will tell the user
# what's missing if they're triggered without complete credentials).
_s3_partial = any([S3_ACCESS_KEY, S3_SECRET_KEY, S3_BUCKET_NAME])
_s3_complete = all([S3_ACCESS_KEY, S3_SECRET_KEY, S3_BUCKET_NAME])
if _s3_partial and not _s3_complete:
    print(
        "\n⚠️  S3 config is partially set — /s3upload and /s3leech will be unavailable until\n"
        "   S3_ACCESS_KEY, S3_SECRET_KEY and S3_BUCKET_NAME are all filled in.\n"
    )
elif _s3_complete:
    _endpoint_label = S3_ENDPOINT_URL if S3_ENDPOINT_URL else "AWS S3 (default)"
    print(f"\n☁️  S3 enabled → bucket=<{S3_BUCKET_NAME}> region=<{S3_REGION}> endpoint=<{_endpoint_label}>\n")

credentials = {
    "API_ID": API_ID,
    "API_HASH": API_HASH,
    "BOT_TOKEN": BOT_TOKEN,
    "USER_ID": USER_ID,
    "DUMP_ID": DUMP_ID,
    "S3_ACCESS_KEY": S3_ACCESS_KEY,
    "S3_SECRET_KEY": S3_SECRET_KEY,
    "S3_BUCKET_NAME": S3_BUCKET_NAME,
    "S3_ENDPOINT_URL": S3_ENDPOINT_URL,
    "S3_REGION": S3_REGION,
    "AM_PLAYLIST_URL": AM_PLAYLIST_URL,
    "AM_ARTIST_URL": AM_ARTIST_URL,
    "AM_MEDIA_TOKEN": AM_MEDIA_TOKEN,
    "AM_AUTH_TOKEN": AM_AUTH_TOKEN,
    "AM_ALBUM_LIMIT": AM_ALBUM_LIMIT,
    "AM_MV_LIMIT": AM_MV_LIMIT,
    "AM_SONGLIST_AUTO": AM_SONGLIST_AUTO,
}

with open('/content/Telegram-Leecher/credentials.json', 'w') as file:
    file.write(json.dumps(credentials))


# --- Songlist fetch (optional): pull /content/songlist.txt from SONGLIST_URL ---
if SONGLIST_URL and not os.path.exists("/content/songlist.txt"):
    try:
        if SONGLIST_URL.startswith("s3://"):
            import boto3
            _b, _k = SONGLIST_URL[5:].split("/", 1)
            _c = boto3.client("s3", aws_access_key_id=S3_ACCESS_KEY,
                              aws_secret_access_key=S3_SECRET_KEY,
                              endpoint_url=S3_ENDPOINT_URL or None,
                              region_name=S3_REGION)
            _c.download_file(_b, _k, "/content/songlist.txt")
        else:
            import urllib.request
            urllib.request.urlretrieve(SONGLIST_URL, "/content/songlist.txt")
        print("songlist.txt fetched:", os.path.getsize("/content/songlist.txt"), "bytes")
    except Exception as _e:
        print("songlist fetch failed:", _e)
if AM_SONGLIST_AUTO and os.path.exists("/content/songlist.txt"):
    print("SONGLIST AUTO: ON — bot will start the songlist download by itself.")
elif AM_SONGLIST_AUTO:
    print("SONGLIST AUTO: ON but /content/songlist.txt MISSING — bot will idle until you add it.")

Working = False

if os.path.exists("/content/Telegram-Leecher/my_bot.session"):
    os.remove("/content/Telegram-Leecher/my_bot.session") # Remove previous bot session

print("\rStarting Bot....")

# !cd /content/Telegram-Leecher/ && python3 -m colab_leecher #type:ignore
# Out:
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:294: SyntaxWarning: invalid escape sequence '\d'
#   lines_video = [l for l in lines if ' Video: ' in l and re.search('\d+x\d+', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:367: SyntaxWarning: invalid escape sequence '\d'
#   rotation_lines = [l for l in lines if 'rotate          :' in l and re.search('\d+$', l)]
# /usr/local/lib/python3.12/dist-packages/moviepy/video/io/ffmpeg_reader.py:370: SyntaxWarning: invalid escape sequence '\d'
#   match = re.search('\d+$', rotation_line)
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if event.key is 'enter':
#
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ...
